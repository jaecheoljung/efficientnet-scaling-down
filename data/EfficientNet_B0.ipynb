# %% [markdown]
# #102 Flowers Classification
# This Project is done using Google Colaboratory.
# 1st you have to mount google drive with Colab and place dataset in zipped format on Google drive to access it.
# This dataset contains flower images of 102 categories. Training images are 6552, validation images are 818 and test images are 819.
# I have achieved top1 accuracy 95.73% and top5 accuracy 99.63% on test set. This project is done using a ResNet18(pretrained on imagenet).

# %% [markdown]
# Next cell is for installation of PyTorch on Google Colab

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)

# !tar -zxvf drive/My\ Drive/flower_data.tar.gz # this line copies the flowers dataset from Google drive to Google Colab and also Unzip it for further processing.
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive
# train/
# train/101/
# train/101/image_07994.jpg
# train/101/image_07960.jpg
# train/101/image_07947.jpg
# train/101/image_07993.jpg
# train/101/image_07945.jpg
# train/101/image_07973.jpg
# train/101/image_07972.jpg
# train/101/image_07991.jpg
# train/101/image_07977.jpg
# train/101/image_07982.jpg
# train/101/image_07948.jpg
# train/101/image_07969.jpg
# train/101/image_07966.jpg
# train/101/image_07957.jpg
# train/101/image_07979.jpg
# train/101/image_07989.jpg
# train/101/image_07974.jpg
# train/101/image_07961.jpg
# train/101/image_07956.jpg
# train/101/image_07998.jpg
# train/101/image_07990.jpg
# train/101/image_07968.jpg
# train/101/image_07986.jpg
# train/101/image_07967.jpg
# train/101/image_07955.jpg
# train/101/image_07978.jpg
# train/101/image_07944.jpg
# train/101/image_07995.jpg
# train/101/image_07958.jpg
# train/101/image_07981.jpg
# train/101/image_07959.jpg
# train/101/image_07943.jpg
# train/101/image_07980.jpg
# train/101/image_07987.jpg
# train/101/image_07954.jpg
# train/101/image_07965.jpg
# train/101/image_07964.jpg
# train/101/image_07975.jpg
# train/101/image_07950.jpg
# train/101/image_07946.jpg
# train/101/image_07942.jpg
# train/101/image_07976.jpg
# train/101/image_07971.jpg
# train/101/image_07984.jpg
# train/101/image_07992.jpg
# train/101/image_07953.jpg
# train/101/image_07996.jpg
# train/101/image_07999.jpg
# train/101/image_07997.jpg
# train/56/
# train/56/image_02796.jpg
# train/56/image_02859.jpg
# train/56/image_02812.jpg
# train/56/image_02832.jpg
# train/56/image_02854.jpg
# train/56/image_02810.jpg
# train/56/image_02838.jpg
# train/56/image_02765.jpg
# train/56/image_02826.jpg
# train/56/image_02816.jpg
# train/56/image_02831.jpg
# train/56/image_02806.jpg
# train/56/image_02767.jpg
# train/56/image_02757.jpg
# train/56/image_02781.jpg
# train/56/image_02756.jpg
# train/56/image_02830.jpg
# train/56/image_02845.jpg
# train/56/image_02758.jpg
# train/56/image_02860.jpg
# train/56/image_02829.jpg
# train/56/image_02834.jpg
# train/56/image_02811.jpg
# train/56/image_02803.jpg
# train/56/image_02856.jpg
# train/56/image_02818.jpg
# train/56/image_02861.jpg
# train/56/image_02780.jpg
# train/56/image_02761.jpg
# train/56/image_02824.jpg
# train/56/image_02809.jpg
# train/56/image_02835.jpg
# train/56/image_02797.jpg
# train/56/image_02819.jpg
# train/56/image_02753.jpg
# train/56/image_02759.jpg
# train/56/image_02776.jpg
# train/56/image_02817.jpg
# train/56/image_02827.jpg
# train/56/image_02836.jpg
# train/56/image_02822.jpg
# train/56/image_02778.jpg
# train/56/image_02754.jpg
# train/56/image_02813.jpg
# train/56/image_02755.jpg
# train/56/image_02787.jpg
# train/56/image_02840.jpg
# train/56/image_02783.jpg
# train/56/image_02793.jpg
# train/56/image_02814.jpg
# train/56/image_02807.jpg
# train/56/image_02823.jpg
# train/56/image_02848.jpg
# train/56/image_02798.jpg
# train/56/image_02794.jpg
# train/56/image_02815.jpg
# train/56/image_02828.jpg
# train/56/image_02837.jpg
# train/56/image_02768.jpg
# train/56/image_02804.jpg
# train/56/image_02777.jpg
# train/56/image_02842.jpg
# train/56/image_02839.jpg
# train/56/image_02789.jpg
# train/56/image_02847.jpg
# train/56/image_02784.jpg
# train/56/image_02790.jpg
# train/56/image_02760.jpg
# train/56/image_02820.jpg
# train/56/image_02786.jpg
# train/56/image_02775.jpg
# train/56/image_02774.jpg
# train/56/image_02846.jpg
# train/56/image_02770.jpg
# train/56/image_02802.jpg
# train/56/image_02763.jpg
# train/56/image_02851.jpg
# train/56/image_02766.jpg
# train/56/image_02762.jpg
# train/56/image_02850.jpg
# train/56/image_02853.jpg
# train/56/image_02852.jpg
# train/56/image_02855.jpg
# train/56/image_02799.jpg
# train/56/image_02782.jpg
# train/56/image_02800.jpg
# train/56/image_02791.jpg
# train/56/image_02833.jpg
# train/56/image_02764.jpg
# train/56/image_02795.jpg
# train/56/image_02843.jpg
# train/56/image_02801.jpg
# train/98/
# train/98/image_07824.jpg
# train/98/image_07775.jpg
# train/98/image_07774.jpg
# train/98/image_07788.jpg
# train/98/image_07779.jpg
# train/98/image_07822.jpg
# train/98/image_07812.jpg
# train/98/image_07754.jpg
# train/98/image_07830.jpg
# train/98/image_07765.jpg
# train/98/image_07829.jpg
# train/98/image_07813.jpg
# train/98/image_07819.jpg
# train/98/image_07802.jpg
# train/98/image_07768.jpg
# train/98/image_07784.jpg
# train/98/image_07751.jpg
# train/98/image_07773.jpg
# train/98/image_07832.jpg
# train/98/image_07794.jpg
# train/98/image_07825.jpg
# train/98/image_07806.jpg
# train/98/image_07807.jpg
# train/98/image_07808.jpg
# train/98/image_07800.jpg
# train/98/image_07786.jpg
# train/98/image_07785.jpg
# train/98/image_07767.jpg
# train/98/image_07811.jpg
# train/98/image_07816.jpg
# train/98/image_07821.jpg
# train/98/image_07762.jpg
# train/98/image_07793.jpg
# train/98/image_07752.jpg
# train/98/image_07823.jpg
# train/98/image_07814.jpg
# train/98/image_07771.jpg
# train/98/image_07791.jpg
# train/98/image_07789.jpg
# train/98/image_07755.jpg
# train/98/image_07817.jpg
# train/98/image_07815.jpg
# train/98/image_07795.jpg
# train/98/image_07756.jpg
# train/98/image_07818.jpg
# train/98/image_07783.jpg
# train/98/image_07761.jpg
# train/98/image_07828.jpg
# train/98/image_07798.jpg
# train/98/image_07799.jpg
# train/98/image_07776.jpg
# train/98/image_07759.jpg
# train/98/image_07797.jpg
# train/98/image_07763.jpg
# train/98/image_07780.jpg
# train/98/image_07809.jpg
# train/98/image_07770.jpg
# train/98/image_07760.jpg
# train/98/image_07781.jpg
# train/98/image_07804.jpg
# train/98/image_07826.jpg
# train/98/image_07801.jpg
# train/98/image_07790.jpg
# train/98/image_07805.jpg
# train/98/image_07772.jpg
# train/98/image_07782.jpg
# train/98/image_07803.jpg
# train/98/image_07831.jpg
# train/34/
# train/34/image_06932.jpg
# train/34/image_06960.jpg
# train/34/image_06967.jpg
# train/34/image_06937.jpg
# train/34/image_06934.jpg
# train/34/image_06968.jpg
# train/34/image_06942.jpg
# train/34/image_06965.jpg
# train/34/image_06940.jpg
# train/34/image_06943.jpg
# train/34/image_06936.jpg
# train/34/image_06958.jpg
# train/34/image_06966.jpg
# train/34/image_06947.jpg
# train/34/image_06945.jpg
# train/34/image_06956.jpg
# train/34/image_06951.jpg
# train/34/image_06952.jpg
# train/34/image_06946.jpg
# train/34/image_06930.jpg
# train/34/image_06935.jpg
# train/34/image_06944.jpg
# train/34/image_06962.jpg
# train/34/image_06938.jpg
# train/34/image_06953.jpg
# train/34/image_06957.jpg
# train/34/image_06948.jpg
# train/34/image_06931.jpg
# train/39/
# train/39/image_07037.jpg
# train/39/image_08081.jpg
# train/39/image_07012.jpg
# train/39/image_07024.jpg
# train/39/image_07030.jpg
# train/39/image_07007.jpg
# train/39/image_08080.jpg
# train/39/image_07021.jpg
# train/39/image_07025.jpg
# train/39/image_07028.jpg
# train/39/image_07009.jpg
# train/39/image_07040.jpg
# train/39/image_07029.jpg
# train/39/image_07017.jpg
# train/39/image_07022.jpg
# train/39/image_07045.jpg
# train/39/image_07026.jpg
# train/39/image_07027.jpg
# train/39/image_07032.jpg
# train/39/image_07023.jpg
# train/39/image_07038.jpg
# train/39/image_07033.jpg
# train/39/image_07011.jpg
# train/39/image_07041.jpg
# train/39/image_07034.jpg
# train/39/image_07008.jpg
# train/39/image_07014.jpg
# train/39/image_07044.jpg
# train/39/image_07019.jpg
# train/39/image_07020.jpg
# train/39/image_07042.jpg
# train/39/image_07031.jpg
# train/39/image_07015.jpg
# train/50/
# train/50/image_06540.jpg
# train/50/image_06564.jpg
# train/50/image_06326.jpg
# train/50/image_06334.jpg
# train/50/image_06551.jpg
# train/50/image_06539.jpg
# train/50/image_06345.jpg
# train/50/image_06549.jpg
# train/50/image_06327.jpg
# train/50/image_06343.jpg
# train/50/image_06566.jpg
# train/50/image_06308.jpg
# train/50/image_06565.jpg
# train/50/image_06330.jpg
# train/50/image_06563.jpg
# train/50/image_06328.jpg
# train/50/image_06556.jpg
# train/50/image_06561.jpg
# train/50/image_06299.jpg
# train/50/image_06531.jpg
# train/50/image_06303.jpg
# train/50/image_06543.jpg
# train/50/image_06553.jpg
# train/50/image_06307.jpg
# train/50/image_06302.jpg
# train/50/image_06301.jpg
# train/50/image_06316.jpg
# train/50/image_06312.jpg
# train/50/image_06529.jpg
# train/50/image_06306.jpg
# train/50/image_06548.jpg
# train/50/image_06557.jpg
# train/50/image_06559.jpg
# train/50/image_06300.jpg
# train/50/image_06304.jpg
# train/50/image_06323.jpg
# train/50/image_06322.jpg
# train/50/image_06336.jpg
# train/50/image_06560.jpg
# train/50/image_06532.jpg
# train/50/image_06310.jpg
# train/50/image_06298.jpg
# train/50/image_06538.jpg
# train/50/image_06545.jpg
# train/50/image_06317.jpg
# train/50/image_06542.jpg
# train/50/image_06569.jpg
# train/50/image_06313.jpg
# train/50/image_06335.jpg
# train/50/image_06535.jpg
# train/50/image_06309.jpg
# train/50/image_06533.jpg
# train/50/image_06537.jpg
# train/50/image_06332.jpg
# train/50/image_06329.jpg
# train/50/image_06314.jpg
# train/50/image_06333.jpg
# train/50/image_06337.jpg
# train/50/image_06341.jpg
# train/50/image_06315.jpg
# train/50/image_06340.jpg
# train/50/image_06338.jpg
# train/50/image_06555.jpg
# train/50/image_06536.jpg
# train/50/image_06554.jpg
# train/50/image_06567.jpg
# train/50/image_06570.jpg
# train/50/image_06530.jpg
# train/50/image_06568.jpg
# train/50/image_06339.jpg
# train/50/image_06344.jpg
# train/50/image_06342.jpg
# train/50/image_06325.jpg
# train/71/
# train/71/image_04526.jpg
# train/71/image_04516.jpg
# train/71/image_04536.jpg
# train/71/image_04531.jpg
# train/71/image_04505.jpg
# train/71/image_04486.jpg
# train/71/image_04525.jpg
# train/71/image_04551.jpg
# train/71/image_04508.jpg
# train/71/image_04546.jpg
# train/71/image_04549.jpg
# train/71/image_04483.jpg
# train/71/image_04530.jpg
# train/71/image_04484.jpg
# train/71/image_04501.jpg
# train/71/image_04544.jpg
# train/71/image_04481.jpg
# train/71/image_04538.jpg
# train/71/image_04543.jpg
# train/71/image_04522.jpg
# train/71/image_04510.jpg
# train/71/image_04534.jpg
# train/71/image_04529.jpg
# train/71/image_04540.jpg
# train/71/image_04503.jpg
# train/71/image_04552.jpg
# train/71/image_04542.jpg
# train/71/image_04556.jpg
# train/71/image_04541.jpg
# train/71/image_08089.jpg
# train/71/image_04511.jpg
# train/71/image_04506.jpg
# train/71/image_04509.jpg
# train/71/image_04548.jpg
# train/71/image_04490.jpg
# train/71/image_04494.jpg
# train/71/image_04545.jpg
# train/71/image_04497.jpg
# train/71/image_04489.jpg
# train/71/image_04527.jpg
# train/71/image_04535.jpg
# train/71/image_04495.jpg
# train/71/image_04520.jpg
# train/71/image_04521.jpg
# train/71/image_04496.jpg
# train/71/image_04532.jpg
# train/71/image_04533.jpg
# train/71/image_04547.jpg
# train/71/image_04500.jpg
# train/71/image_04504.jpg
# train/71/image_04550.jpg
# train/71/image_04492.jpg
# train/71/image_04487.jpg
# train/71/image_04537.jpg
# train/71/image_04507.jpg
# train/71/image_04493.jpg
# train/71/image_04523.jpg
# train/71/image_04498.jpg
# train/71/image_04528.jpg
# train/71/image_04553.jpg
# train/71/image_04518.jpg
# train/71/image_04499.jpg
# train/71/image_04485.jpg
# train/71/image_04491.jpg
# train/77/
# train/77/image_00179.jpg
# train/77/image_00237.jpg
# train/77/image_00121.jpg
# train/77/image_00048.jpg
# train/77/image_00215.jpg
# train/77/image_00036.jpg
# train/77/image_00038.jpg
# train/77/image_00154.jpg
# train/77/image_00015.jpg
# train/77/image_00069.jpg
# train/77/image_00249.jpg
# train/77/image_00110.jpg
# train/77/image_00084.jpg
# train/77/image_00247.jpg
# train/77/image_00158.jpg
# train/77/image_00019.jpg
# train/77/image_00233.jpg
# train/77/image_00205.jpg
# train/77/image_00145.jpg
# train/77/image_00217.jpg
# train/77/image_00198.jpg
# train/77/image_00113.jpg
# train/77/image_00180.jpg
# train/77/image_00227.jpg
# train/77/image_00026.jpg
# train/77/image_00165.jpg
# train/77/image_00211.jpg
# train/77/image_00235.jpg
# train/77/image_00043.jpg
# train/77/image_00210.jpg
# train/77/image_00221.jpg
# train/77/image_00142.jpg
# train/77/image_00206.jpg
# train/77/image_00105.jpg
# train/77/image_00164.jpg
# train/77/image_00003.jpg
# train/77/image_00194.jpg
# train/77/image_00070.jpg
# train/77/image_00080.jpg
# train/77/image_00131.jpg
# train/77/image_00027.jpg
# train/77/image_00195.jpg
# train/77/image_00167.jpg
# train/77/image_00074.jpg
# train/77/image_00007.jpg
# train/77/image_00219.jpg
# train/77/image_00153.jpg
# train/77/image_00094.jpg
# train/77/image_00031.jpg
# train/77/image_00216.jpg
# train/77/image_00056.jpg
# train/77/image_00135.jpg
# train/77/image_00095.jpg
# train/77/image_00138.jpg
# train/77/image_00119.jpg
# train/77/image_00022.jpg
# train/77/image_00226.jpg
# train/77/image_00236.jpg
# train/77/image_00224.jpg
# train/77/image_00127.jpg
# train/77/image_00030.jpg
# train/77/image_00243.jpg
# train/77/image_00067.jpg
# train/77/image_00171.jpg
# train/77/image_00057.jpg
# train/77/image_00087.jpg
# train/77/image_00102.jpg
# train/77/image_00032.jpg
# train/77/image_00018.jpg
# train/77/image_00034.jpg
# train/77/image_00123.jpg
# train/77/image_00073.jpg
# train/77/image_00106.jpg
# train/77/image_00089.jpg
# train/77/image_00096.jpg
# train/77/image_00108.jpg
# train/77/image_00141.jpg
# train/77/image_00199.jpg
# train/77/image_00062.jpg
# train/77/image_00238.jpg
# train/77/image_00013.jpg
# train/77/image_00016.jpg
# train/77/image_00223.jpg
# train/77/image_00192.jpg
# train/77/image_00183.jpg
# train/77/image_00058.jpg
# train/77/image_00229.jpg
# train/77/image_00232.jpg
# train/77/image_00149.jpg
# train/77/image_00209.jpg
# train/77/image_00042.jpg
# train/77/image_00001.jpg
# train/77/image_00168.jpg
# train/77/image_00136.jpg
# train/77/image_00185.jpg
# train/77/image_00128.jpg
# train/77/image_00189.jpg
# train/77/image_00012.jpg
# train/77/image_00079.jpg
# train/77/image_00147.jpg
# train/77/image_00064.jpg
# train/77/image_00214.jpg
# train/77/image_00076.jpg
# train/77/image_00086.jpg
# train/77/image_00010.jpg
# train/77/image_00184.jpg
# train/77/image_00240.jpg
# train/77/image_00101.jpg
# train/77/image_00196.jpg
# train/77/image_00075.jpg
# train/77/image_00159.jpg
# train/77/image_00088.jpg
# train/77/image_00100.jpg
# train/77/image_00020.jpg
# train/77/image_00040.jpg
# train/77/image_00054.jpg
# train/77/image_00213.jpg
# train/77/image_00193.jpg
# train/77/image_00044.jpg
# train/77/image_00156.jpg
# train/77/image_00208.jpg
# train/77/image_00126.jpg
# train/77/image_00107.jpg
# train/77/image_00066.jpg
# train/77/image_00220.jpg
# train/77/image_00008.jpg
# train/77/image_00041.jpg
# train/77/image_00103.jpg
# train/77/image_00162.jpg
# train/77/image_00197.jpg
# train/77/image_00047.jpg
# train/77/image_00151.jpg
# train/77/image_00098.jpg
# train/77/image_00090.jpg
# train/77/image_00150.jpg
# train/77/image_00115.jpg
# train/77/image_00097.jpg
# train/77/image_00250.jpg
# train/77/image_00166.jpg
# train/77/image_00120.jpg
# train/77/image_00241.jpg
# train/77/image_00083.jpg
# train/77/image_00045.jpg
# train/77/image_00157.jpg
# train/77/image_00111.jpg
# train/77/image_00109.jpg
# train/77/image_00017.jpg
# train/77/image_00014.jpg
# train/77/image_00201.jpg
# train/77/image_00009.jpg
# train/77/image_00169.jpg
# train/77/image_00129.jpg
# train/77/image_00186.jpg
# train/77/image_00230.jpg
# train/77/image_00077.jpg
# train/77/image_00068.jpg
# train/77/image_00021.jpg
# train/77/image_00046.jpg
# train/77/image_00049.jpg
# train/77/image_00170.jpg
# train/77/image_00175.jpg
# train/77/image_00085.jpg
# train/77/image_00091.jpg
# train/77/image_00244.jpg
# train/77/image_00173.jpg
# train/77/image_00082.jpg
# train/77/image_00139.jpg
# train/77/image_00148.jpg
# train/77/image_00023.jpg
# train/77/image_00182.jpg
# train/77/image_00039.jpg
# train/77/image_00053.jpg
# train/77/image_00037.jpg
# train/77/image_00093.jpg
# train/77/image_00134.jpg
# train/77/image_00125.jpg
# train/77/image_00172.jpg
# train/77/image_00144.jpg
# train/77/image_00181.jpg
# train/77/image_00242.jpg
# train/77/image_00133.jpg
# train/77/image_00190.jpg
# train/77/image_00161.jpg
# train/77/image_00130.jpg
# train/77/image_00234.jpg
# train/77/image_00051.jpg
# train/77/image_00124.jpg
# train/77/image_00055.jpg
# train/77/image_00118.jpg
# train/77/image_00035.jpg
# train/77/image_00052.jpg
# train/77/image_00140.jpg
# train/77/image_00228.jpg
# train/77/image_00002.jpg
# train/77/image_00207.jpg
# train/77/image_00225.jpg
# train/77/image_00152.jpg
# train/77/image_00004.jpg
# train/77/image_00146.jpg
# train/77/image_00163.jpg
# train/77/image_00122.jpg
# train/77/image_00117.jpg
# train/77/image_00011.jpg
# train/77/image_00033.jpg
# train/77/image_00155.jpg
# train/36/
# train/36/image_04399.jpg
# train/36/image_04367.jpg
# train/36/image_04341.jpg
# train/36/image_04391.jpg
# train/36/image_04374.jpg
# train/36/image_04368.jpg
# train/36/image_04348.jpg
# train/36/image_04359.jpg
# train/36/image_04342.jpg
# train/36/image_04386.jpg
# train/36/image_04389.jpg
# train/36/image_04329.jpg
# train/36/image_04371.jpg
# train/36/image_04396.jpg
# train/36/image_04395.jpg
# train/36/image_04331.jpg
# train/36/image_04358.jpg
# train/36/image_04375.jpg
# train/36/image_04360.jpg
# train/36/image_04343.jpg
# train/36/image_04332.jpg
# train/36/image_04370.jpg
# train/36/image_04330.jpg
# train/36/image_04355.jpg
# train/36/image_04349.jpg
# train/36/image_04387.jpg
# train/36/image_04327.jpg
# train/36/image_04377.jpg
# train/36/image_04326.jpg
# train/36/image_04384.jpg
# train/36/image_04381.jpg
# train/36/image_04390.jpg
# train/36/image_04339.jpg
# train/36/image_04357.jpg
# train/36/image_04336.jpg
# train/36/image_04340.jpg
# train/36/image_04347.jpg
# train/36/image_04376.jpg
# train/36/image_04362.jpg
# train/36/image_04398.jpg
# train/36/image_04383.jpg
# train/36/image_04363.jpg
# train/36/image_04380.jpg
# train/36/image_04361.jpg
# train/36/image_04379.jpg
# train/36/image_04366.jpg
# train/36/image_04388.jpg
# train/36/image_04385.jpg
# train/36/image_04346.jpg
# train/36/image_04353.jpg
# train/36/image_04394.jpg
# train/36/image_04365.jpg
# train/36/image_04328.jpg
# train/36/image_04369.jpg
# train/36/image_04378.jpg
# train/36/image_04397.jpg
# train/36/image_04345.jpg
# train/36/image_04335.jpg
# train/36/image_04356.jpg
# train/36/image_04338.jpg
# train/36/image_04372.jpg
# train/36/image_04337.jpg
# train/19/
# train/19/image_06190.jpg
# train/19/image_06193.jpg
# train/19/image_06166.jpg
# train/19/image_06167.jpg
# train/19/image_06182.jpg
# train/19/image_06176.jpg
# train/19/image_06188.jpg
# train/19/image_06149.jpg
# train/19/image_06157.jpg
# train/19/image_06184.jpg
# train/19/image_06189.jpg
# train/19/image_06180.jpg
# train/19/image_06173.jpg
# train/19/image_06161.jpg
# train/19/image_06181.jpg
# train/19/image_06178.jpg
# train/19/image_06169.jpg
# train/19/image_06179.jpg
# train/19/image_06171.jpg
# train/19/image_06150.jpg
# train/19/image_06177.jpg
# train/19/image_06156.jpg
# train/19/image_06192.jpg
# train/19/image_06185.jpg
# train/19/image_06153.jpg
# train/19/image_06164.jpg
# train/19/image_06194.jpg
# train/19/image_06151.jpg
# train/19/image_06154.jpg
# train/19/image_06160.jpg
# train/19/image_06168.jpg
# train/19/image_06191.jpg
# train/19/image_06172.jpg
# train/19/image_06163.jpg
# train/19/image_06174.jpg
# train/19/image_06152.jpg
# train/19/image_06162.jpg
# train/19/image_06183.jpg
# train/24/
# train/24/image_06817.jpg
# train/24/image_06834.jpg
# train/24/image_08053.jpg
# train/24/image_06831.jpg
# train/24/image_06829.jpg
# train/24/image_06828.jpg
# train/24/image_06838.jpg
# train/24/image_06830.jpg
# train/24/image_06816.jpg
# train/24/image_06839.jpg
# train/24/image_06825.jpg
# train/24/image_06823.jpg
# train/24/image_08049.jpg
# train/24/image_06824.jpg
# train/24/image_06840.jpg
# train/24/image_06826.jpg
# train/24/image_06843.jpg
# train/24/image_06844.jpg
# train/24/image_06837.jpg
# train/24/image_06832.jpg
# train/24/image_06845.jpg
# train/24/image_06822.jpg
# train/24/image_06846.jpg
# train/24/image_06820.jpg
# train/24/image_06827.jpg
# train/24/image_08048.jpg
# train/24/image_08050.jpg
# train/24/image_06833.jpg
# train/24/image_06821.jpg
# train/24/image_06848.jpg
# train/24/image_06835.jpg
# train/24/image_08052.jpg
# train/24/image_08051.jpg
# train/24/image_06841.jpg
# train/24/image_06842.jpg
# train/92/
# train/92/image_03045.jpg
# train/92/image_03072.jpg
# train/92/image_03062.jpg
# train/92/image_03093.jpg
# train/92/image_03086.jpg
# train/92/image_03057.jpg
# train/92/image_03068.jpg
# train/92/image_03078.jpg
# train/92/image_03046.jpg
# train/92/image_03035.jpg
# train/92/image_03089.jpg
# train/92/image_03033.jpg
# train/92/image_03037.jpg
# train/92/image_03066.jpg
# train/92/image_03038.jpg
# train/92/image_03087.jpg
# train/92/image_03061.jpg
# train/92/image_03073.jpg
# train/92/image_03047.jpg
# train/92/image_03088.jpg
# train/92/image_03080.jpg
# train/92/image_03083.jpg
# train/92/image_03082.jpg
# train/92/image_03069.jpg
# train/92/image_03040.jpg
# train/92/image_03077.jpg
# train/92/image_03091.jpg
# train/92/image_03060.jpg
# train/92/image_03030.jpg
# train/92/image_03074.jpg
# train/92/image_03094.jpg
# train/92/image_03050.jpg
# train/92/image_03036.jpg
# train/92/image_03053.jpg
# train/92/image_03070.jpg
# train/92/image_03055.jpg
# train/92/image_03084.jpg
# train/92/image_03029.jpg
# train/92/image_03090.jpg
# train/92/image_03071.jpg
# train/92/image_03051.jpg
# train/92/image_03081.jpg
# train/92/image_03042.jpg
# train/92/image_03067.jpg
# train/92/image_03059.jpg
# train/92/image_03092.jpg
# train/92/image_03085.jpg
# train/92/image_03043.jpg
# train/92/image_03034.jpg
# train/92/image_03064.jpg
# train/92/image_03079.jpg
# train/92/image_03076.jpg
# train/92/image_03031.jpg
# train/84/
# train/84/image_02595.jpg
# train/84/image_02630.jpg
# train/84/image_02625.jpg
# train/84/image_02607.jpg
# train/84/image_02638.jpg
# train/84/image_02599.jpg
# train/84/image_02577.jpg
# train/84/image_02592.jpg
# train/84/image_02609.jpg
# train/84/image_02556.jpg
# train/84/image_02614.jpg
# train/84/image_02560.jpg
# train/84/image_02620.jpg
# train/84/image_02633.jpg
# train/84/image_02558.jpg
# train/84/image_02554.jpg
# train/84/image_02603.jpg
# train/84/image_02593.jpg
# train/84/image_02616.jpg
# train/84/image_02578.jpg
# train/84/image_02571.jpg
# train/84/image_02626.jpg
# train/84/image_02553.jpg
# train/84/image_02606.jpg
# train/84/image_02564.jpg
# train/84/image_02596.jpg
# train/84/image_02575.jpg
# train/84/image_02605.jpg
# train/84/image_02601.jpg
# train/84/image_02569.jpg
# train/84/image_02562.jpg
# train/84/image_02619.jpg
# train/84/image_02585.jpg
# train/84/image_02634.jpg
# train/84/image_02559.jpg
# train/84/image_02636.jpg
# train/84/image_02611.jpg
# train/84/image_02628.jpg
# train/84/image_02573.jpg
# train/84/image_02594.jpg
# train/84/image_02588.jpg
# train/84/image_02618.jpg
# train/84/image_02589.jpg
# train/84/image_02566.jpg
# train/84/image_02561.jpg
# train/84/image_02602.jpg
# train/84/image_02622.jpg
# train/84/image_02590.jpg
# train/84/image_02597.jpg
# train/84/image_02600.jpg
# train/84/image_02624.jpg
# train/84/image_02584.jpg
# train/84/image_02587.jpg
# train/84/image_02565.jpg
# train/84/image_02612.jpg
# train/84/image_02627.jpg
# train/84/image_02570.jpg
# train/84/image_02555.jpg
# train/84/image_02617.jpg
# train/84/image_02580.jpg
# train/84/image_02629.jpg
# train/84/image_02623.jpg
# train/84/image_02632.jpg
# train/84/image_02579.jpg
# train/84/image_02631.jpg
# train/84/image_02608.jpg
# train/97/
# train/97/image_07703.jpg
# train/97/image_07690.jpg
# train/97/image_07705.jpg
# train/97/image_07726.jpg
# train/97/image_07742.jpg
# train/97/image_07744.jpg
# train/97/image_07691.jpg
# train/97/image_07702.jpg
# train/97/image_07748.jpg
# train/97/image_07686.jpg
# train/97/image_07716.jpg
# train/97/image_07733.jpg
# train/97/image_07685.jpg
# train/97/image_07720.jpg
# train/97/image_07687.jpg
# train/97/image_07694.jpg
# train/97/image_07730.jpg
# train/97/image_07722.jpg
# train/97/image_07701.jpg
# train/97/image_07711.jpg
# train/97/image_07692.jpg
# train/97/image_07707.jpg
# train/97/image_07721.jpg
# train/97/image_07706.jpg
# train/97/image_07724.jpg
# train/97/image_07688.jpg
# train/97/image_07746.jpg
# train/97/image_07693.jpg
# train/97/image_07750.jpg
# train/97/image_07743.jpg
# train/97/image_07741.jpg
# train/97/image_07749.jpg
# train/97/image_07738.jpg
# train/97/image_07732.jpg
# train/97/image_07728.jpg
# train/97/image_07712.jpg
# train/97/image_07729.jpg
# train/97/image_07698.jpg
# train/97/image_07704.jpg
# train/97/image_07740.jpg
# train/97/image_07725.jpg
# train/97/image_07734.jpg
# train/97/image_07717.jpg
# train/97/image_07736.jpg
# train/97/image_07689.jpg
# train/97/image_07735.jpg
# train/97/image_07714.jpg
# train/97/image_07747.jpg
# train/97/image_07700.jpg
# train/97/image_07713.jpg
# train/97/image_07695.jpg
# train/97/image_07710.jpg
# train/97/image_07715.jpg
# train/97/image_07731.jpg
# train/60/
# train/60/image_02989.jpg
# train/60/image_02973.jpg
# train/60/image_03027.jpg
# train/60/image_02927.jpg
# train/60/image_02940.jpg
# train/60/image_02946.jpg
# train/60/image_03024.jpg
# train/60/image_03017.jpg
# train/60/image_02999.jpg
# train/60/image_03001.jpg
# train/60/image_03009.jpg
# train/60/image_02941.jpg
# train/60/image_02926.jpg
# train/60/image_03020.jpg
# train/60/image_03002.jpg
# train/60/image_02949.jpg
# train/60/image_03012.jpg
# train/60/image_03014.jpg
# train/60/image_02957.jpg
# train/60/image_02950.jpg
# train/60/image_02966.jpg
# train/60/image_02967.jpg
# train/60/image_02947.jpg
# train/60/image_02930.jpg
# train/60/image_02938.jpg
# train/60/image_02931.jpg
# train/60/image_02954.jpg
# train/60/image_03023.jpg
# train/60/image_02980.jpg
# train/60/image_03013.jpg
# train/60/image_02951.jpg
# train/60/image_02963.jpg
# train/60/image_03005.jpg
# train/60/image_02956.jpg
# train/60/image_02995.jpg
# train/60/image_03028.jpg
# train/60/image_03015.jpg
# train/60/image_02986.jpg
# train/60/image_02945.jpg
# train/60/image_02998.jpg
# train/60/image_02922.jpg
# train/60/image_02925.jpg
# train/60/image_03025.jpg
# train/60/image_02993.jpg
# train/60/image_03019.jpg
# train/60/image_02952.jpg
# train/60/image_02972.jpg
# train/60/image_03006.jpg
# train/60/image_02983.jpg
# train/60/image_02969.jpg
# train/60/image_02935.jpg
# train/60/image_03018.jpg
# train/60/image_03004.jpg
# train/60/image_03022.jpg
# train/60/image_02942.jpg
# train/60/image_02964.jpg
# train/60/image_02988.jpg
# train/60/image_02970.jpg
# train/60/image_02994.jpg
# train/60/image_02921.jpg
# train/60/image_02982.jpg
# train/60/image_02985.jpg
# train/60/image_02944.jpg
# train/60/image_02960.jpg
# train/60/image_02943.jpg
# train/60/image_02924.jpg
# train/60/image_02929.jpg
# train/60/image_02934.jpg
# train/60/image_02920.jpg
# train/60/image_02955.jpg
# train/60/image_02990.jpg
# train/60/image_02962.jpg
# train/60/image_02953.jpg
# train/60/image_02979.jpg
# train/60/image_03007.jpg
# train/60/image_03021.jpg
# train/60/image_02965.jpg
# train/60/image_02991.jpg
# train/60/image_02976.jpg
# train/60/image_02984.jpg
# train/60/image_03011.jpg
# train/60/image_03010.jpg
# train/60/image_02968.jpg
# train/60/image_02939.jpg
# train/60/image_02975.jpg
# train/74/
# train/74/image_01259.jpg
# train/74/image_01158.jpg
# train/74/image_01225.jpg
# train/74/image_01163.jpg
# train/74/image_01226.jpg
# train/74/image_01208.jpg
# train/74/image_01205.jpg
# train/74/image_01203.jpg
# train/74/image_01289.jpg
# train/74/image_01270.jpg
# train/74/image_01299.jpg
# train/74/image_01235.jpg
# train/74/image_01224.jpg
# train/74/image_01174.jpg
# train/74/image_01216.jpg
# train/74/image_01268.jpg
# train/74/image_01162.jpg
# train/74/image_01189.jpg
# train/74/image_01267.jpg
# train/74/image_01262.jpg
# train/74/image_01199.jpg
# train/74/image_01297.jpg
# train/74/image_01188.jpg
# train/74/image_01152.jpg
# train/74/image_01239.jpg
# train/74/image_01302.jpg
# train/74/image_01248.jpg
# train/74/image_01300.jpg
# train/74/image_01286.jpg
# train/74/image_01230.jpg
# train/74/image_01277.jpg
# train/74/image_01146.jpg
# train/74/image_01285.jpg
# train/74/image_01245.jpg
# train/74/image_01168.jpg
# train/74/image_01167.jpg
# train/74/image_01183.jpg
# train/74/image_01145.jpg
# train/74/image_01247.jpg
# train/74/image_01275.jpg
# train/74/image_01243.jpg
# train/74/image_01156.jpg
# train/74/image_01282.jpg
# train/74/image_01166.jpg
# train/74/image_01169.jpg
# train/74/image_01184.jpg
# train/74/image_01221.jpg
# train/74/image_01197.jpg
# train/74/image_01181.jpg
# train/74/image_01281.jpg
# train/74/image_01308.jpg
# train/74/image_01211.jpg
# train/74/image_01214.jpg
# train/74/image_01265.jpg
# train/74/image_01229.jpg
# train/74/image_01231.jpg
# train/74/image_01273.jpg
# train/74/image_01304.jpg
# train/74/image_01198.jpg
# train/74/image_01246.jpg
# train/74/image_01227.jpg
# train/74/image_01196.jpg
# train/74/image_01148.jpg
# train/74/image_01160.jpg
# train/74/image_01218.jpg
# train/74/image_01291.jpg
# train/74/image_01296.jpg
# train/74/image_01185.jpg
# train/74/image_01153.jpg
# train/74/image_01236.jpg
# train/74/image_01311.jpg
# train/74/image_01234.jpg
# train/74/image_01154.jpg
# train/74/image_01238.jpg
# train/74/image_01292.jpg
# train/74/image_01215.jpg
# train/74/image_01177.jpg
# train/74/image_01171.jpg
# train/74/image_01313.jpg
# train/74/image_01172.jpg
# train/74/image_01178.jpg
# train/74/image_01207.jpg
# train/74/image_01237.jpg
# train/74/image_01255.jpg
# train/74/image_01193.jpg
# train/74/image_01272.jpg
# train/74/image_01263.jpg
# train/74/image_01306.jpg
# train/74/image_01179.jpg
# train/74/image_01194.jpg
# train/74/image_01284.jpg
# train/74/image_01210.jpg
# train/74/image_01301.jpg
# train/74/image_01298.jpg
# train/74/image_01257.jpg
# train/74/image_01253.jpg
# train/74/image_01287.jpg
# train/74/image_01159.jpg
# train/74/image_01295.jpg
# train/74/image_01242.jpg
# train/74/image_01303.jpg
# train/74/image_01143.jpg
# train/74/image_01161.jpg
# train/74/image_01290.jpg
# train/74/image_01232.jpg
# train/74/image_01187.jpg
# train/74/image_01283.jpg
# train/74/image_01269.jpg
# train/74/image_01240.jpg
# train/74/image_01258.jpg
# train/74/image_01150.jpg
# train/74/image_01250.jpg
# train/74/image_01212.jpg
# train/74/image_01201.jpg
# train/74/image_01155.jpg
# train/74/image_01206.jpg
# train/74/image_01233.jpg
# train/74/image_01170.jpg
# train/74/image_01147.jpg
# train/74/image_01309.jpg
# train/74/image_01202.jpg
# train/74/image_01182.jpg
# train/74/image_01180.jpg
# train/74/image_01278.jpg
# train/74/image_01195.jpg
# train/74/image_01204.jpg
# train/74/image_01261.jpg
# train/74/image_01144.jpg
# train/74/image_01186.jpg
# train/74/image_01280.jpg
# train/74/image_01217.jpg
# train/74/image_01228.jpg
# train/74/image_01252.jpg
# train/74/image_01219.jpg
# train/74/image_01293.jpg
# train/74/image_01220.jpg
# train/74/image_01223.jpg
# train/74/image_01176.jpg
# train/74/image_01279.jpg
# train/74/image_01274.jpg
# train/74/image_01164.jpg
# train/74/image_01241.jpg
# train/76/
# train/76/image_02453.jpg
# train/76/image_02482.jpg
# train/76/image_02541.jpg
# train/76/image_02473.jpg
# train/76/image_02524.jpg
# train/76/image_02520.jpg
# train/76/image_02493.jpg
# train/76/image_02544.jpg
# train/76/image_02516.jpg
# train/76/image_02474.jpg
# train/76/image_02521.jpg
# train/76/image_02517.jpg
# train/76/image_02531.jpg
# train/76/image_02464.jpg
# train/76/image_02477.jpg
# train/76/image_02454.jpg
# train/76/image_02547.jpg
# train/76/image_02451.jpg
# train/76/image_02532.jpg
# train/76/image_02452.jpg
# train/76/image_02506.jpg
# train/76/image_02552.jpg
# train/76/image_02466.jpg
# train/76/image_02500.jpg
# train/76/image_02499.jpg
# train/76/image_02509.jpg
# train/76/image_02545.jpg
# train/76/image_02546.jpg
# train/76/image_02455.jpg
# train/76/image_02492.jpg
# train/76/image_02488.jpg
# train/76/image_02447.jpg
# train/76/image_02510.jpg
# train/76/image_02526.jpg
# train/76/image_02449.jpg
# train/76/image_02503.jpg
# train/76/image_02462.jpg
# train/76/image_02483.jpg
# train/76/image_02486.jpg
# train/76/image_02489.jpg
# train/76/image_02534.jpg
# train/76/image_02542.jpg
# train/76/image_02540.jpg
# train/76/image_02543.jpg
# train/76/image_02518.jpg
# train/76/image_02469.jpg
# train/76/image_02487.jpg
# train/76/image_02460.jpg
# train/76/image_02465.jpg
# train/76/image_02505.jpg
# train/76/image_02497.jpg
# train/76/image_02527.jpg
# train/76/image_02515.jpg
# train/76/image_02502.jpg
# train/76/image_02471.jpg
# train/76/image_02539.jpg
# train/76/image_02551.jpg
# train/76/image_02507.jpg
# train/76/image_02468.jpg
# train/76/image_02480.jpg
# train/76/image_02498.jpg
# train/76/image_02535.jpg
# train/76/image_02528.jpg
# train/76/image_02463.jpg
# train/76/image_02495.jpg
# train/76/image_02459.jpg
# train/76/image_02522.jpg
# train/76/image_02448.jpg
# train/76/image_02490.jpg
# train/76/image_02536.jpg
# train/76/image_02549.jpg
# train/76/image_02533.jpg
# train/76/image_02478.jpg
# train/76/image_02476.jpg
# train/76/image_02508.jpg
# train/76/image_02491.jpg
# train/76/image_02538.jpg
# train/76/image_02548.jpg
# train/76/image_02470.jpg
# train/76/image_02519.jpg
# train/76/image_02511.jpg
# train/76/image_02461.jpg
# train/76/image_02450.jpg
# train/65/
# train/65/image_03261.jpg
# train/65/image_03251.jpg
# train/65/image_03219.jpg
# train/65/image_03246.jpg
# train/65/image_03207.jpg
# train/65/image_03257.jpg
# train/65/image_03209.jpg
# train/65/image_03272.jpg
# train/65/image_03216.jpg
# train/65/image_03212.jpg
# train/65/image_03185.jpg
# train/65/image_03278.jpg
# train/65/image_03228.jpg
# train/65/image_03232.jpg
# train/65/image_03202.jpg
# train/65/image_03198.jpg
# train/65/image_03253.jpg
# train/65/image_03242.jpg
# train/65/image_03182.jpg
# train/65/image_03221.jpg
# train/65/image_03217.jpg
# train/65/image_03260.jpg
# train/65/image_03191.jpg
# train/65/image_03210.jpg
# train/65/image_03271.jpg
# train/65/image_03213.jpg
# train/65/image_03201.jpg
# train/65/image_03215.jpg
# train/65/image_03225.jpg
# train/65/image_03190.jpg
# train/65/image_03262.jpg
# train/65/image_03231.jpg
# train/65/image_03263.jpg
# train/65/image_03281.jpg
# train/65/image_03245.jpg
# train/65/image_03192.jpg
# train/65/image_03227.jpg
# train/65/image_03270.jpg
# train/65/image_03235.jpg
# train/65/image_03237.jpg
# train/65/image_03206.jpg
# train/65/image_03249.jpg
# train/65/image_03204.jpg
# train/65/image_03259.jpg
# train/65/image_03194.jpg
# train/65/image_03255.jpg
# train/65/image_03234.jpg
# train/65/image_03229.jpg
# train/65/image_03226.jpg
# train/65/image_03267.jpg
# train/65/image_03230.jpg
# train/65/image_03184.jpg
# train/65/image_03280.jpg
# train/65/image_03218.jpg
# train/65/image_03240.jpg
# train/65/image_03247.jpg
# train/65/image_03244.jpg
# train/65/image_03183.jpg
# train/65/image_03220.jpg
# train/65/image_03189.jpg
# train/65/image_03203.jpg
# train/65/image_03233.jpg
# train/65/image_03239.jpg
# train/65/image_03268.jpg
# train/65/image_03214.jpg
# train/65/image_03208.jpg
# train/65/image_03199.jpg
# train/65/image_03238.jpg
# train/65/image_03256.jpg
# train/65/image_03275.jpg
# train/65/image_03236.jpg
# train/65/image_03248.jpg
# train/65/image_03277.jpg
# train/65/image_03223.jpg
# train/65/image_03187.jpg
# train/65/image_03283.jpg
# train/65/image_03195.jpg
# train/65/image_03266.jpg
# train/65/image_03186.jpg
# train/65/image_03196.jpg
# train/65/image_03264.jpg
# train/65/image_03200.jpg
# train/65/image_03282.jpg
# train/65/image_03273.jpg
# train/65/image_03205.jpg
# train/65/image_03274.jpg
# train/65/image_03265.jpg
# train/65/image_03254.jpg
# train/58/
# train/58/image_02708.jpg
# train/58/image_02720.jpg
# train/58/image_02704.jpg
# train/58/image_02652.jpg
# train/58/image_02685.jpg
# train/58/image_02669.jpg
# train/58/image_02664.jpg
# train/58/image_02648.jpg
# train/58/image_02723.jpg
# train/58/image_02729.jpg
# train/58/image_02702.jpg
# train/58/image_02750.jpg
# train/58/image_02745.jpg
# train/58/image_02660.jpg
# train/58/image_02748.jpg
# train/58/image_02751.jpg
# train/58/image_02655.jpg
# train/58/image_02665.jpg
# train/58/image_02673.jpg
# train/58/image_02714.jpg
# train/58/image_02711.jpg
# train/58/image_02707.jpg
# train/58/image_02730.jpg
# train/58/image_02703.jpg
# train/58/image_02710.jpg
# train/58/image_02670.jpg
# train/58/image_02658.jpg
# train/58/image_02706.jpg
# train/58/image_02718.jpg
# train/58/image_02659.jpg
# train/58/image_02657.jpg
# train/58/image_02728.jpg
# train/58/image_02747.jpg
# train/58/image_02724.jpg
# train/58/image_02744.jpg
# train/58/image_02746.jpg
# train/58/image_02682.jpg
# train/58/image_02640.jpg
# train/58/image_02697.jpg
# train/58/image_02735.jpg
# train/58/image_02713.jpg
# train/58/image_02716.jpg
# train/58/image_02733.jpg
# train/58/image_02650.jpg
# train/58/image_02717.jpg
# train/58/image_02639.jpg
# train/58/image_02725.jpg
# train/58/image_02674.jpg
# train/58/image_02712.jpg
# train/58/image_02696.jpg
# train/58/image_02679.jpg
# train/58/image_02686.jpg
# train/58/image_02646.jpg
# train/58/image_02740.jpg
# train/58/image_02647.jpg
# train/58/image_02689.jpg
# train/58/image_02645.jpg
# train/58/image_02666.jpg
# train/58/image_02641.jpg
# train/58/image_02678.jpg
# train/58/image_02732.jpg
# train/58/image_02684.jpg
# train/58/image_02661.jpg
# train/58/image_02671.jpg
# train/58/image_02736.jpg
# train/58/image_02699.jpg
# train/58/image_02749.jpg
# train/58/image_02731.jpg
# train/58/image_02643.jpg
# train/58/image_02668.jpg
# train/58/image_02683.jpg
# train/58/image_02701.jpg
# train/58/image_02727.jpg
# train/58/image_02698.jpg
# train/58/image_02739.jpg
# train/58/image_02715.jpg
# train/58/image_02680.jpg
# train/58/image_02651.jpg
# train/58/image_02654.jpg
# train/58/image_02644.jpg
# train/58/image_02688.jpg
# train/58/image_02692.jpg
# train/58/image_02662.jpg
# train/58/image_02693.jpg
# train/58/image_02709.jpg
# train/58/image_02667.jpg
# train/45/
# train/45/image_07128.jpg
# train/45/image_07159.jpg
# train/45/image_07138.jpg
# train/45/image_07148.jpg
# train/45/image_07124.jpg
# train/45/image_07132.jpg
# train/45/image_07123.jpg
# train/45/image_07150.jpg
# train/45/image_07149.jpg
# train/45/image_07145.jpg
# train/45/image_07133.jpg
# train/45/image_07141.jpg
# train/45/image_07146.jpg
# train/45/image_07161.jpg
# train/45/image_07134.jpg
# train/45/image_07151.jpg
# train/45/image_07129.jpg
# train/45/image_07154.jpg
# train/45/image_08098.jpg
# train/45/image_07158.jpg
# train/45/image_07147.jpg
# train/45/image_07135.jpg
# train/45/image_07130.jpg
# train/45/image_07153.jpg
# train/45/image_07131.jpg
# train/45/image_07125.jpg
# train/45/image_07156.jpg
# train/45/image_07126.jpg
# train/45/image_07136.jpg
# train/45/image_07152.jpg
# train/45/image_07157.jpg
# train/45/image_07143.jpg
# train/45/image_07144.jpg
# train/35/
# train/35/image_06982.jpg
# train/35/image_08085.jpg
# train/35/image_06991.jpg
# train/35/image_06995.jpg
# train/35/image_06980.jpg
# train/35/image_06994.jpg
# train/35/image_07003.jpg
# train/35/image_06972.jpg
# train/35/image_08087.jpg
# train/35/image_06998.jpg
# train/35/image_07001.jpg
# train/35/image_07000.jpg
# train/35/image_06997.jpg
# train/35/image_07002.jpg
# train/35/image_06970.jpg
# train/35/image_06974.jpg
# train/35/image_06976.jpg
# train/35/image_06971.jpg
# train/35/image_06989.jpg
# train/35/image_06981.jpg
# train/35/image_06993.jpg
# train/35/image_06996.jpg
# train/35/image_06969.jpg
# train/35/image_06987.jpg
# train/35/image_06988.jpg
# train/35/image_06990.jpg
# train/35/image_06985.jpg
# train/35/image_06975.jpg
# train/35/image_06983.jpg
# train/35/image_06999.jpg
# train/35/image_08086.jpg
# train/35/image_06973.jpg
# train/35/image_06979.jpg
# train/42/
# train/42/image_05688.jpg
# train/42/image_05737.jpg
# train/42/image_05736.jpg
# train/42/image_05742.jpg
# train/42/image_05710.jpg
# train/42/image_05685.jpg
# train/42/image_05727.jpg
# train/42/image_05740.jpg
# train/42/image_05702.jpg
# train/42/image_05721.jpg
# train/42/image_05724.jpg
# train/42/image_05691.jpg
# train/42/image_05719.jpg
# train/42/image_05717.jpg
# train/42/image_05707.jpg
# train/42/image_05732.jpg
# train/42/image_05725.jpg
# train/42/image_05741.jpg
# train/42/image_05715.jpg
# train/42/image_05709.jpg
# train/42/image_05700.jpg
# train/42/image_05705.jpg
# train/42/image_05695.jpg
# train/42/image_05689.jpg
# train/42/image_05698.jpg
# train/42/image_05729.jpg
# train/42/image_05697.jpg
# train/42/image_05716.jpg
# train/42/image_05699.jpg
# train/42/image_05734.jpg
# train/42/image_05743.jpg
# train/42/image_05687.jpg
# train/42/image_05738.jpg
# train/42/image_05720.jpg
# train/42/image_05726.jpg
# train/42/image_05694.jpg
# train/42/image_05704.jpg
# train/42/image_05708.jpg
# train/42/image_05692.jpg
# train/42/image_05706.jpg
# train/42/image_05703.jpg
# train/42/image_05714.jpg
# train/42/image_05686.jpg
# train/42/image_05739.jpg
# train/42/image_05718.jpg
# train/42/image_05722.jpg
# train/42/image_05693.jpg
# train/42/image_05728.jpg
# train/42/image_05733.jpg
# train/43/
# train/43/image_02375.jpg
# train/43/image_02337.jpg
# train/43/image_02428.jpg
# train/43/image_02376.jpg
# train/43/image_02418.jpg
# train/43/image_02378.jpg
# train/43/image_02367.jpg
# train/43/image_02343.jpg
# train/43/image_02404.jpg
# train/43/image_02382.jpg
# train/43/image_02393.jpg
# train/43/image_02402.jpg
# train/43/image_02347.jpg
# train/43/image_02352.jpg
# train/43/image_02358.jpg
# train/43/image_02340.jpg
# train/43/image_02392.jpg
# train/43/image_02399.jpg
# train/43/image_02398.jpg
# train/43/image_02441.jpg
# train/43/image_02422.jpg
# train/43/image_02372.jpg
# train/43/image_02327.jpg
# train/43/image_02362.jpg
# train/43/image_02377.jpg
# train/43/image_02385.jpg
# train/43/image_02373.jpg
# train/43/image_02391.jpg
# train/43/image_02410.jpg
# train/43/image_02430.jpg
# train/43/image_02350.jpg
# train/43/image_02438.jpg
# train/43/image_02356.jpg
# train/43/image_02423.jpg
# train/43/image_02379.jpg
# train/43/image_02366.jpg
# train/43/image_02331.jpg
# train/43/image_02442.jpg
# train/43/image_02406.jpg
# train/43/image_02405.jpg
# train/43/image_02381.jpg
# train/43/image_02322.jpg
# train/43/image_02403.jpg
# train/43/image_02339.jpg
# train/43/image_02396.jpg
# train/43/image_02440.jpg
# train/43/image_02420.jpg
# train/43/image_02353.jpg
# train/43/image_02316.jpg
# train/43/image_02325.jpg
# train/43/image_02361.jpg
# train/43/image_02321.jpg
# train/43/image_02364.jpg
# train/43/image_02334.jpg
# train/43/image_02409.jpg
# train/43/image_02357.jpg
# train/43/image_02324.jpg
# train/43/image_02444.jpg
# train/43/image_02387.jpg
# train/43/image_02323.jpg
# train/43/image_02413.jpg
# train/43/image_02380.jpg
# train/43/image_02417.jpg
# train/43/image_02427.jpg
# train/43/image_02351.jpg
# train/43/image_02416.jpg
# train/43/image_02437.jpg
# train/43/image_02439.jpg
# train/43/image_02326.jpg
# train/43/image_02348.jpg
# train/43/image_02384.jpg
# train/43/image_02395.jpg
# train/43/image_02332.jpg
# train/43/image_02445.jpg
# train/43/image_02383.jpg
# train/43/image_02319.jpg
# train/43/image_02434.jpg
# train/43/image_02360.jpg
# train/43/image_02411.jpg
# train/43/image_02354.jpg
# train/43/image_02317.jpg
# train/43/image_02320.jpg
# train/43/image_02318.jpg
# train/43/image_02424.jpg
# train/43/image_02374.jpg
# train/43/image_02341.jpg
# train/43/image_02432.jpg
# train/43/image_02388.jpg
# train/43/image_02363.jpg
# train/43/image_02328.jpg
# train/43/image_02408.jpg
# train/43/image_02359.jpg
# train/43/image_02342.jpg
# train/43/image_02338.jpg
# train/43/image_02415.jpg
# train/43/image_02344.jpg
# train/43/image_02401.jpg
# train/43/image_02390.jpg
# train/43/image_02333.jpg
# train/43/image_02436.jpg
# train/64/
# train/64/image_06136.jpg
# train/64/image_06117.jpg
# train/64/image_06140.jpg
# train/64/image_06108.jpg
# train/64/image_06109.jpg
# train/64/image_06125.jpg
# train/64/image_06111.jpg
# train/64/image_06105.jpg
# train/64/image_06135.jpg
# train/64/image_06107.jpg
# train/64/image_06097.jpg
# train/64/image_06144.jpg
# train/64/image_06118.jpg
# train/64/image_06128.jpg
# train/64/image_06116.jpg
# train/64/image_06102.jpg
# train/64/image_06131.jpg
# train/64/image_06120.jpg
# train/64/image_06112.jpg
# train/64/image_06106.jpg
# train/64/image_06142.jpg
# train/64/image_06114.jpg
# train/64/image_06145.jpg
# train/64/image_06133.jpg
# train/64/image_06124.jpg
# train/64/image_06139.jpg
# train/64/image_06137.jpg
# train/64/image_06101.jpg
# train/64/image_06127.jpg
# train/64/image_06121.jpg
# train/64/image_06147.jpg
# train/64/image_06143.jpg
# train/64/image_06148.jpg
# train/64/image_06113.jpg
# train/64/image_06132.jpg
# train/64/image_06115.jpg
# train/64/image_06119.jpg
# train/64/image_06122.jpg
# train/64/image_06110.jpg
# train/64/image_06103.jpg
# train/64/image_06146.jpg
# train/64/image_06100.jpg
# train/47/
# train/47/image_04954.jpg
# train/47/image_04962.jpg
# train/47/image_04979.jpg
# train/47/image_04968.jpg
# train/47/image_04988.jpg
# train/47/image_04994.jpg
# train/47/image_04983.jpg
# train/47/image_04967.jpg
# train/47/image_04984.jpg
# train/47/image_05016.jpg
# train/47/image_04978.jpg
# train/47/image_04960.jpg
# train/47/image_04971.jpg
# train/47/image_05012.jpg
# train/47/image_04992.jpg
# train/47/image_05002.jpg
# train/47/image_04964.jpg
# train/47/image_04980.jpg
# train/47/image_04973.jpg
# train/47/image_04963.jpg
# train/47/image_05019.jpg
# train/47/image_05001.jpg
# train/47/image_04956.jpg
# train/47/image_04986.jpg
# train/47/image_04975.jpg
# train/47/image_04961.jpg
# train/47/image_05010.jpg
# train/47/image_04974.jpg
# train/47/image_04999.jpg
# train/47/image_04997.jpg
# train/47/image_04959.jpg
# train/47/image_05017.jpg
# train/47/image_05009.jpg
# train/47/image_05015.jpg
# train/47/image_04970.jpg
# train/47/image_04998.jpg
# train/47/image_04996.jpg
# train/47/image_04969.jpg
# train/47/image_05008.jpg
# train/47/image_05004.jpg
# train/47/image_05003.jpg
# train/47/image_04995.jpg
# train/47/image_04987.jpg
# train/47/image_05000.jpg
# train/47/image_05011.jpg
# train/47/image_04981.jpg
# train/47/image_05018.jpg
# train/47/image_04990.jpg
# train/47/image_04977.jpg
# train/47/image_04976.jpg
# train/47/image_04958.jpg
# train/47/image_04965.jpg
# train/47/image_05005.jpg
# train/47/image_04985.jpg
# train/47/image_04955.jpg
# train/47/image_04972.jpg
# train/47/image_04953.jpg
# train/47/image_04982.jpg
# train/47/image_04991.jpg
# train/47/image_05014.jpg
# train/47/image_05006.jpg
# train/87/
# train/87/image_05471.jpg
# train/87/image_05486.jpg
# train/87/image_05517.jpg
# train/87/image_05478.jpg
# train/87/image_05464.jpg
# train/87/image_05514.jpg
# train/87/image_05503.jpg
# train/87/image_05522.jpg
# train/87/image_05505.jpg
# train/87/image_05477.jpg
# train/87/image_05460.jpg
# train/87/image_05475.jpg
# train/87/image_05491.jpg
# train/87/image_05498.jpg
# train/87/image_05472.jpg
# train/87/image_05513.jpg
# train/87/image_05481.jpg
# train/87/image_05480.jpg
# train/87/image_05516.jpg
# train/87/image_05496.jpg
# train/87/image_05470.jpg
# train/87/image_05494.jpg
# train/87/image_05461.jpg
# train/87/image_05490.jpg
# train/87/image_05501.jpg
# train/87/image_05510.jpg
# train/87/image_05500.jpg
# train/87/image_05499.jpg
# train/87/image_05519.jpg
# train/87/image_05489.jpg
# train/87/image_05474.jpg
# train/87/image_05492.jpg
# train/87/image_05479.jpg
# train/87/image_05509.jpg
# train/87/image_05518.jpg
# train/87/image_05521.jpg
# train/87/image_05463.jpg
# train/87/image_05473.jpg
# train/87/image_05482.jpg
# train/87/image_05506.jpg
# train/87/image_05511.jpg
# train/87/image_05515.jpg
# train/87/image_05476.jpg
# train/87/image_05483.jpg
# train/87/image_05465.jpg
# train/87/image_05468.jpg
# train/87/image_05497.jpg
# train/87/image_05512.jpg
# train/87/image_05504.jpg
# train/87/image_05467.jpg
# train/87/image_05495.jpg
# train/78/
# train/78/image_01958.jpg
# train/78/image_01834.jpg
# train/78/image_01908.jpg
# train/78/image_01923.jpg
# train/78/image_01846.jpg
# train/78/image_01909.jpg
# train/78/image_01950.jpg
# train/78/image_01883.jpg
# train/78/image_01852.jpg
# train/78/image_01859.jpg
# train/78/image_01873.jpg
# train/78/image_01835.jpg
# train/78/image_01892.jpg
# train/78/image_01864.jpg
# train/78/image_01889.jpg
# train/78/image_01868.jpg
# train/78/image_01917.jpg
# train/78/image_01945.jpg
# train/78/image_01831.jpg
# train/78/image_01933.jpg
# train/78/image_01913.jpg
# train/78/image_01838.jpg
# train/78/image_01941.jpg
# train/78/image_01947.jpg
# train/78/image_01841.jpg
# train/78/image_01925.jpg
# train/78/image_01850.jpg
# train/78/image_01861.jpg
# train/78/image_01828.jpg
# train/78/image_01881.jpg
# train/78/image_01869.jpg
# train/78/image_01847.jpg
# train/78/image_01866.jpg
# train/78/image_01955.jpg
# train/78/image_01905.jpg
# train/78/image_01935.jpg
# train/78/image_01878.jpg
# train/78/image_01915.jpg
# train/78/image_01934.jpg
# train/78/image_01899.jpg
# train/78/image_01879.jpg
# train/78/image_01851.jpg
# train/78/image_01936.jpg
# train/78/image_01898.jpg
# train/78/image_01871.jpg
# train/78/image_01863.jpg
# train/78/image_01890.jpg
# train/78/image_01906.jpg
# train/78/image_01924.jpg
# train/78/image_01876.jpg
# train/78/image_01867.jpg
# train/78/image_01827.jpg
# train/78/image_01829.jpg
# train/78/image_01912.jpg
# train/78/image_01956.jpg
# train/78/image_01911.jpg
# train/78/image_01930.jpg
# train/78/image_01845.jpg
# train/78/image_01943.jpg
# train/78/image_01902.jpg
# train/78/image_01963.jpg
# train/78/image_01872.jpg
# train/78/image_01926.jpg
# train/78/image_01840.jpg
# train/78/image_01870.jpg
# train/78/image_01836.jpg
# train/78/image_01860.jpg
# train/78/image_01921.jpg
# train/78/image_01882.jpg
# train/78/image_01901.jpg
# train/78/image_01854.jpg
# train/78/image_01837.jpg
# train/78/image_01896.jpg
# train/78/image_01940.jpg
# train/78/image_01939.jpg
# train/78/image_01951.jpg
# train/78/image_01927.jpg
# train/78/image_01884.jpg
# train/78/image_01886.jpg
# train/78/image_01857.jpg
# train/78/image_01858.jpg
# train/78/image_01960.jpg
# train/78/image_01880.jpg
# train/78/image_01904.jpg
# train/78/image_01946.jpg
# train/78/image_01918.jpg
# train/78/image_01900.jpg
# train/78/image_01895.jpg
# train/78/image_01948.jpg
# train/78/image_01833.jpg
# train/78/image_01959.jpg
# train/78/image_01842.jpg
# train/78/image_01887.jpg
# train/78/image_01957.jpg
# train/78/image_01920.jpg
# train/78/image_01875.jpg
# train/78/image_01865.jpg
# train/78/image_01885.jpg
# train/78/image_01942.jpg
# train/78/image_01849.jpg
# train/78/image_01932.jpg
# train/78/image_01954.jpg
# train/78/image_01916.jpg
# train/78/image_01907.jpg
# train/78/image_01891.jpg
# train/78/image_01839.jpg
# train/78/image_01832.jpg
# train/78/image_01877.jpg
# train/78/image_01952.jpg
# train/78/image_01853.jpg
# train/78/image_01897.jpg
# train/78/image_01961.jpg
# train/15/
# ...
# valid/47/
# valid/47/image_05007.jpg
# valid/47/image_04957.jpg
# valid/47/image_04989.jpg
# valid/87/
# valid/87/image_05502.jpg
# valid/87/image_05520.jpg
# valid/87/image_05507.jpg
# valid/87/image_05484.jpg
# valid/87/image_05508.jpg
# valid/87/image_05487.jpg
# valid/78/
# valid/78/image_01894.jpg
# valid/78/image_01844.jpg
# valid/78/image_01937.jpg
# valid/78/image_01922.jpg
# valid/78/image_01862.jpg
# valid/78/image_01962.jpg
# valid/78/image_01910.jpg
# valid/78/image_01938.jpg
# valid/78/image_01914.jpg
# valid/78/image_01944.jpg
# valid/78/image_01929.jpg
# valid/15/
# valid/15/image_06353.jpg
# valid/15/image_06346.jpg
# valid/15/image_06358.jpg
# valid/15/image_06354.jpg
# valid/15/image_06385.jpg
# valid/15/image_06386.jpg
# valid/15/image_06389.jpg
# valid/13/
# valid/13/image_05759.jpg
# valid/13/image_05763.jpg
# valid/13/image_05772.jpg
# valid/13/image_05749.jpg
# valid/13/image_05783.jpg
# valid/72/
# valid/72/image_03568.jpg
# valid/72/image_03587.jpg
# valid/72/image_03561.jpg
# valid/72/image_03632.jpg
# valid/72/image_03576.jpg
# valid/72/image_03559.jpg
# valid/72/image_03565.jpg
# valid/72/image_03584.jpg
# valid/102/
# valid/102/image_08014.jpg
# valid/102/image_08041.jpg
# valid/102/image_08002.jpg
# valid/102/image_08040.jpg
# valid/102/image_08038.jpg
# valid/102/image_08006.jpg
# valid/18/
# valid/18/image_04315.jpg
# valid/18/image_04317.jpg
# valid/18/image_04311.jpg
# valid/18/image_04278.jpg
# valid/18/image_04248.jpg
# valid/18/image_04252.jpg
# valid/18/image_04261.jpg
# valid/18/image_04299.jpg
# valid/18/image_04263.jpg
# valid/18/image_04312.jpg
# valid/18/image_04290.jpg
# valid/52/
# valid/52/image_04225.jpg
# valid/52/image_04207.jpg
# valid/52/image_04191.jpg
# valid/52/image_04215.jpg
# valid/52/image_04182.jpg
# valid/52/image_04173.jpg
# valid/52/image_04172.jpg
# valid/52/image_04163.jpg
# valid/52/image_04235.jpg
# valid/52/image_04238.jpg
# valid/80/
# valid/80/image_02021.jpg
# valid/80/image_01991.jpg
# valid/80/image_02017.jpg
# valid/80/image_01979.jpg
# valid/80/image_02050.jpg
# valid/80/image_01989.jpg
# valid/80/image_01992.jpg
# valid/80/image_02005.jpg
# valid/80/image_01972.jpg
# valid/80/image_01975.jpg
# valid/80/image_02011.jpg
# valid/80/image_02042.jpg
# valid/12/
# valid/12/image_03998.jpg
# valid/12/image_03997.jpg
# valid/12/image_04072.jpg
# valid/12/image_04013.jpg
# valid/12/image_04080.jpg
# valid/26/
# valid/26/image_06506.jpg
# valid/26/image_06501.jpg
# valid/26/image_06516.jpg
# valid/46/
# valid/46/image_01050.jpg
# valid/46/image_01142.jpg
# valid/46/image_01095.jpg
# valid/46/image_01138.jpg
# valid/46/image_01100.jpg
# valid/46/image_01086.jpg
# valid/46/image_01132.jpg
# valid/46/image_00977.jpg
# valid/46/image_01030.jpg
# valid/46/image_00983.jpg
# valid/46/image_01076.jpg
# valid/46/image_01047.jpg
# valid/46/image_01029.jpg
# valid/46/image_01034.jpg
# valid/46/image_01040.jpg
# valid/46/image_01065.jpg
# valid/46/image_00949.jpg
# valid/46/image_01129.jpg
# valid/4/
# valid/4/image_05657.jpg
# valid/4/image_05638.jpg
# valid/4/image_05681.jpg
# valid/4/image_05660.jpg
# valid/4/image_05680.jpg
# valid/4/image_05677.jpg
# valid/53/
# valid/53/image_03667.jpg
# valid/53/image_03693.jpg
# valid/53/image_03702.jpg
# valid/53/image_03668.jpg
# valid/53/image_03670.jpg
# valid/53/image_03733.jpg
# valid/53/image_03655.jpg
# valid/53/image_03656.jpg
# valid/53/image_03654.jpg
# valid/91/
# valid/91/image_04843.jpg
# valid/91/image_04835.jpg
# valid/91/image_04829.jpg
# valid/91/image_04872.jpg
# valid/91/image_04878.jpg
# valid/91/image_08059.jpg
# valid/91/image_04844.jpg
# valid/91/image_04854.jpg
# valid/91/image_04848.jpg
# valid/51/
# valid/51/image_01354.jpg
# valid/51/image_01391.jpg
# valid/51/image_03943.jpg
# valid/51/image_03917.jpg
# valid/51/image_03938.jpg
# valid/51/image_03933.jpg
# valid/51/image_01352.jpg
# valid/51/image_03975.jpg
# valid/51/image_03961.jpg
# valid/51/image_01389.jpg
# valid/51/image_03937.jpg
# valid/51/image_01469.jpg
# valid/51/image_03946.jpg
# valid/51/image_03916.jpg
# valid/51/image_01473.jpg
# valid/51/image_01326.jpg
# valid/51/image_01322.jpg
# valid/51/image_01459.jpg
# valid/51/image_01363.jpg
# valid/51/image_03951.jpg
# valid/51/image_01439.jpg
# valid/51/image_01425.jpg
# valid/51/image_01315.jpg
# valid/51/image_01419.jpg
# valid/51/image_01414.jpg
# valid/51/image_03927.jpg
# valid/51/image_03974.jpg
# valid/51/image_01346.jpg
# valid/68/
# valid/68/image_05908.jpg
# valid/68/image_05915.jpg
# valid/68/image_05926.jpg
# valid/68/image_05919.jpg
# valid/68/image_05924.jpg
# valid/68/image_05904.jpg
# valid/68/image_05916.jpg
# valid/68/image_05932.jpg
# valid/31/
# valid/31/image_08067.jpg
# valid/31/image_06905.jpg
# valid/63/
# valid/63/image_05871.jpg
# valid/63/image_05876.jpg
# valid/63/image_05894.jpg
# valid/63/image_05867.jpg
# valid/63/image_05853.jpg
# valid/63/image_05861.jpg
# valid/63/image_05857.jpg
# valid/63/image_05898.jpg
# valid/99/
# valid/99/image_07869.jpg
# valid/99/image_07862.jpg
# valid/99/image_08063.jpg
# valid/99/image_07875.jpg
# valid/99/image_07860.jpg
# valid/99/image_07873.jpg
# valid/2/
# valid/2/image_05124.jpg
# valid/2/image_05101.jpg
# valid/2/image_05137.jpg
# valid/2/image_05136.jpg
# valid/2/image_05142.jpg
# valid/2/image_05094.jpg
# valid/70/
# valid/70/image_05326.jpg
# valid/70/image_05280.jpg
# valid/70/image_05303.jpg
# valid/70/image_05284.jpg
# valid/70/image_05289.jpg
# valid/70/image_05296.jpg
# valid/70/image_05321.jpg
# valid/17/
# valid/17/image_03854.jpg
# valid/17/image_03843.jpg
# valid/17/image_03876.jpg
# valid/17/image_03856.jpg
# valid/17/image_03883.jpg
# valid/17/image_03890.jpg
# valid/17/image_03834.jpg
# valid/17/image_03908.jpg
# valid/17/image_03837.jpg
# valid/17/image_03829.jpg
# valid/17/image_03851.jpg
# valid/17/image_03842.jpg
# valid/17/image_03868.jpg
# valid/17/image_03839.jpg
# valid/17/image_03831.jpg
# valid/17/image_03907.jpg
# valid/100/
# valid/100/image_07931.jpg
# valid/100/image_07904.jpg
# valid/100/image_07895.jpg
# valid/100/image_07905.jpg
# valid/100/image_07917.jpg
# valid/100/image_07929.jpg
# valid/83/
# valid/83/image_01701.jpg
# valid/83/image_01787.jpg
# valid/83/image_01765.jpg
# valid/83/image_01747.jpg
# valid/83/image_01766.jpg
# valid/83/image_01697.jpg
# valid/83/image_01817.jpg
# valid/83/image_01780.jpg
# valid/83/image_01712.jpg
# valid/83/image_01811.jpg
# valid/83/image_01703.jpg
# valid/83/image_01769.jpg
# valid/83/image_01739.jpg
# valid/75/
# valid/75/image_02104.jpg
# valid/75/image_02081.jpg
# valid/75/image_02178.jpg
# valid/75/image_02182.jpg
# valid/75/image_02152.jpg
# valid/75/image_02133.jpg
# valid/75/image_02155.jpg
# valid/75/image_02147.jpg
# valid/75/image_02100.jpg
# valid/75/image_02141.jpg
# valid/75/image_02074.jpg
# valid/75/image_02130.jpg
# valid/7/
# valid/7/image_07216.jpg
# valid/81/
# valid/81/image_00896.jpg
# valid/81/image_00820.jpg
# valid/81/image_00859.jpg
# valid/81/image_00919.jpg
# valid/81/image_00892.jpg
# valid/81/image_00784.jpg
# valid/81/image_00895.jpg
# valid/81/image_00903.jpg
# valid/81/image_00860.jpg
# valid/81/image_00909.jpg
# valid/81/image_00853.jpg
# valid/81/image_00893.jpg
# valid/81/image_00914.jpg
# valid/81/image_00920.jpg
# valid/81/image_00848.jpg
# valid/81/image_00863.jpg
# valid/81/image_00809.jpg
# valid/81/image_00904.jpg
# valid/54/
# valid/54/image_05451.jpg
# valid/54/image_05452.jpg
# valid/54/image_05417.jpg
# valid/54/image_05411.jpg
# valid/54/image_05425.jpg
# valid/54/image_05453.jpg
# valid/54/image_05415.jpg
# valid/54/image_05426.jpg
# valid/54/image_05406.jpg
# valid/54/image_05449.jpg
# valid/30/
# valid/30/image_03471.jpg
# valid/30/image_03464.jpg
# valid/30/image_03469.jpg
# valid/30/image_03544.jpg
# valid/30/image_03530.jpg
# valid/30/image_03485.jpg
# valid/30/image_03467.jpg
# valid/30/image_03475.jpg
# valid/30/image_03487.jpg
# valid/30/image_03531.jpg
# valid/82/
# valid/82/image_01683.jpg
# valid/82/image_01693.jpg
# valid/82/image_01625.jpg
# valid/82/image_01643.jpg
# valid/82/image_01596.jpg
# valid/82/image_01658.jpg
# valid/82/image_01592.jpg
# valid/82/image_01671.jpg
# valid/82/image_01649.jpg
# valid/82/image_01659.jpg
# valid/82/image_01690.jpg
# valid/82/image_01691.jpg
# valid/82/image_01640.jpg
# valid/28/
# valid/28/image_05258.jpg
# valid/28/image_05265.jpg
# valid/28/image_05257.jpg
# valid/28/image_05267.jpg
# valid/28/image_05272.jpg
# valid/90/
# valid/90/image_04402.jpg
# valid/90/image_04403.jpg
# valid/9/
# valid/9/image_06414.jpg
# valid/9/image_06420.jpg
# valid/9/image_06398.jpg
# valid/88/
# valid/88/image_00544.jpg
# valid/88/image_00512.jpg
# valid/88/image_00577.jpg
# valid/88/image_00459.jpg
# valid/88/image_00461.jpg
# valid/88/image_00595.jpg
# valid/88/image_00554.jpg
# valid/88/image_00574.jpg
# valid/88/image_00547.jpg
# valid/88/image_00533.jpg
# valid/88/image_00508.jpg
# valid/88/image_00545.jpg
# valid/88/image_00593.jpg
# valid/88/image_00489.jpg
# valid/88/image_00585.jpg
# valid/88/image_00597.jpg
# valid/88/image_00502.jpg
# valid/88/image_00531.jpg
# valid/88/image_00518.jpg
# valid/88/image_00546.jpg
# valid/88/image_00542.jpg
# valid/88/image_00539.jpg
# valid/88/image_00516.jpg
# valid/88/image_00509.jpg
# valid/88/image_00556.jpg
# valid/16/
# valid/16/image_06671.jpg
# valid/16/image_06691.jpg
# valid/32/
# valid/32/image_05598.jpg
# valid/32/image_05615.jpg
# valid/32/image_05584.jpg
# valid/66/
# valid/66/image_05563.jpg
# valid/66/image_05577.jpg
# valid/66/image_05559.jpg
# valid/66/image_05560.jpg
# valid/66/image_05579.jpg
# valid/66/image_05565.jpg
# valid/49/
# valid/49/image_06209.jpg
# valid/49/image_06216.jpg
# valid/49/image_06210.jpg
# valid/49/image_06228.jpg
# valid/49/image_06240.jpg
# valid/49/image_06230.jpg
# valid/49/image_06222.jpg
# valid/49/image_06235.jpg
# valid/23/
# valid/23/image_03425.jpg
# valid/23/image_03436.jpg
# valid/23/image_03420.jpg
# valid/23/image_03400.jpg
# valid/23/image_03383.jpg
# valid/23/image_03398.jpg
# valid/23/image_03386.jpg
# valid/23/image_03416.jpg
# valid/23/image_03444.jpg
# valid/23/image_03437.jpg
# valid/23/image_03371.jpg
# valid/23/image_03412.jpg
# valid/48/
# valid/48/image_04678.jpg
# valid/48/image_04684.jpg
# valid/48/image_04691.jpg
# valid/48/image_04688.jpg
# valid/48/image_04693.jpg
# valid/48/image_04687.jpg
# valid/48/image_04690.jpg
# valid/48/image_04641.jpg
# valid/48/image_04652.jpg
# valid/57/
# valid/57/image_07255.jpg
# valid/57/image_07247.jpg
# valid/57/image_08145.jpg
# valid/57/image_07239.jpg
# valid/57/image_07254.jpg
# valid/57/image_07262.jpg
# valid/27/
# valid/27/image_06868.jpg
# valid/37/
# valid/37/image_03822.jpg
# valid/37/image_03820.jpg
# valid/37/image_03765.jpg
# valid/37/image_03813.jpg
# valid/37/image_03768.jpg
# valid/37/image_03785.jpg
# valid/37/image_03756.jpg
# valid/37/image_03810.jpg
# valid/38/
# valid/38/image_05829.jpg
# valid/38/image_05830.jpg
# valid/38/image_05819.jpg
# valid/38/image_05845.jpg
# valid/44/
# valid/44/image_01569.jpg
# valid/44/image_01573.jpg
# valid/44/image_01500.jpg
# valid/44/image_01579.jpg
# valid/44/image_01491.jpg
# valid/44/image_01570.jpg
# valid/44/image_01540.jpg
# valid/44/image_01494.jpg
# valid/44/image_01510.jpg
# valid/29/
# valid/29/image_04116.jpg
# valid/29/image_04103.jpg
# valid/29/image_04108.jpg
# valid/29/image_04097.jpg
# valid/29/image_04099.jpg
# valid/29/image_04104.jpg
# valid/29/image_04143.jpg
# valid/55/
# valid/55/image_04734.jpg
# valid/55/image_04739.jpg
# valid/55/image_04702.jpg
# valid/55/image_04722.jpg
# valid/55/image_04696.jpg
# valid/55/image_04753.jpg
# valid/55/image_04760.jpg
# valid/55/image_04720.jpg
# valid/85/
# valid/85/image_04818.jpg
# valid/85/image_04817.jpg
# valid/85/image_04799.jpg
# valid/85/image_04804.jpg
# valid/85/image_04809.jpg
# valid/10/
# valid/10/image_07101.jpg
# valid/10/image_07107.jpg
# valid/10/image_07094.jpg
# valid/10/image_07102.jpg
# valid/33/
# valid/33/image_06481.jpg
# valid/33/image_06455.jpg
# valid/33/image_06441.jpg
# valid/33/image_06443.jpg
# valid/33/image_06485.jpg
# valid/33/image_06444.jpg
# valid/33/image_06468.jpg
# valid/59/
# valid/59/image_05086.jpg
# valid/59/image_05056.jpg
# valid/59/image_05077.jpg
# valid/59/image_05034.jpg
# valid/6/
# valid/6/image_08105.jpg
# valid/22/
# valid/22/image_05361.jpg
# valid/22/image_05376.jpg
# valid/22/image_05368.jpg
# valid/22/image_05352.jpg
# valid/22/image_05398.jpg
# valid/22/image_05381.jpg
# valid/22/image_05388.jpg
# valid/22/image_05364.jpg
# valid/14/
# valid/14/image_06082.jpg
# valid/96/
# valid/96/image_07613.jpg
# valid/96/image_07669.jpg
# valid/96/image_07656.jpg
# valid/96/image_07662.jpg
# valid/96/image_07670.jpg
# valid/96/image_07677.jpg
# valid/96/image_07605.jpg
# valid/96/image_07658.jpg
# valid/96/image_07653.jpg
# valid/96/image_07609.jpg
# valid/21/
# valid/21/image_06778.jpg
# valid/21/image_06784.jpg
# valid/21/image_06788.jpg
# valid/21/image_06804.jpg
# valid/73/
# valid/73/image_00302.jpg
# valid/73/image_00352.jpg
# valid/73/image_00378.jpg
# valid/73/image_00354.jpg
# valid/73/image_00356.jpg
# valid/73/image_00329.jpg
# valid/73/image_00295.jpg
# valid/73/image_00421.jpg
# valid/73/image_00280.jpg
# valid/73/image_00366.jpg
# valid/73/image_00432.jpg
# valid/73/image_00415.jpg
# valid/73/image_00440.jpg
# valid/73/image_00424.jpg
# valid/73/image_00442.jpg
# valid/73/image_00436.jpg
# valid/73/image_00381.jpg
# valid/73/image_00402.jpg
# valid/73/image_00275.jpg
# valid/62/
# valid/62/image_07271.jpg
# valid/62/image_08155.jpg
# valid/62/image_08171.jpg
# valid/95/
# valid/95/image_07502.jpg
# valid/95/image_07512.jpg
# valid/95/image_07485.jpg
# valid/95/image_07475.jpg
# valid/95/image_07588.jpg
# valid/95/image_07581.jpg
# valid/95/image_07575.jpg
# valid/95/image_07510.jpg
# valid/95/image_07513.jpg
# valid/95/image_07580.jpg
# valid/95/image_07585.jpg
# valid/95/image_07471.jpg
# valid/95/image_07484.jpg
# valid/61/
# valid/61/image_06259.jpg
# valid/61/image_06273.jpg
# valid/61/image_06261.jpg
# valid/61/image_06292.jpg
# valid/61/image_06296.jpg
# valid/61/image_06293.jpg
# valid/94/
# valid/94/image_07317.jpg
# valid/94/image_07381.jpg
# valid/94/image_07372.jpg
# valid/94/image_07385.jpg
# valid/94/image_07325.jpg
# valid/94/image_07360.jpg
# valid/94/image_07408.jpg
# valid/94/image_07435.jpg
# valid/94/image_07393.jpg
# valid/94/image_07428.jpg
# valid/94/image_07418.jpg
# valid/94/image_07449.jpg
# valid/94/image_07382.jpg
# valid/94/image_07392.jpg
# valid/93/
# valid/93/image_06048.jpg
# valid/93/image_06024.jpg
# valid/93/image_07303.jpg
# valid/93/image_06044.jpg
# valid/93/image_07302.jpg
# valid/93/image_08113.jpg
# valid/86/
# valid/86/image_02909.jpg
# valid/86/image_02887.jpg
# valid/86/image_02906.jpg
# valid/86/image_02901.jpg
# valid/86/image_02891.jpg
# valid/89/
# valid/89/image_00623.jpg
# valid/89/image_00752.jpg
# valid/89/image_00624.jpg
# valid/89/image_00691.jpg
# valid/89/image_00730.jpg
# valid/89/image_00764.jpg
# valid/89/image_00749.jpg
# valid/89/image_00746.jpg
# valid/89/image_00759.jpg
# valid/89/image_00741.jpg
# valid/89/image_00696.jpg
# valid/89/image_00692.jpg
# valid/89/image_00627.jpg
# valid/89/image_00763.jpg
# valid/89/image_00652.jpg
# valid/89/image_00640.jpg
# valid/25/
# valid/25/image_06584.jpg
# valid/25/image_06572.jpg
# valid/69/
# valid/69/image_05984.jpg
# valid/69/image_05992.jpg
# valid/69/image_06008.jpg
# valid/69/image_05958.jpg
# valid/69/image_05993.jpg
# valid/40/
# valid/40/image_04578.jpg
# valid/40/image_04596.jpg
# valid/40/image_04608.jpg
# valid/40/image_04579.jpg
# valid/40/image_04584.jpg
# valid/1/
# valid/1/image_06763.jpg
# valid/1/image_06765.jpg
# valid/1/image_06739.jpg
# valid/1/image_06756.jpg
# valid/1/image_06755.jpg
# valid/1/image_06749.jpg
# valid/1/image_06769.jpg
# valid/1/image_06758.jpg
# valid/41/
# valid/41/image_02198.jpg
# valid/41/image_02260.jpg
# valid/41/image_02201.jpg
# valid/41/image_02205.jpg
# valid/41/image_02276.jpg
# valid/41/image_02231.jpg
# valid/41/image_02268.jpg
# valid/41/image_02248.jpg
# valid/41/image_02232.jpg
# valid/41/image_02199.jpg
# valid/41/image_02247.jpg
# valid/41/image_02278.jpg
# valid/41/image_02258.jpg
# valid/41/image_02219.jpg
# valid/41/image_02297.jpg
# valid/41/image_02259.jpg
# valid/11/
# valid/11/image_03157.jpg
# valid/11/image_03173.jpg
# valid/11/image_03111.jpg
# valid/11/image_03145.jpg
# valid/11/image_03116.jpg
# valid/11/image_03128.jpg
# valid/11/image_03100.jpg
# valid/11/image_03125.jpg
# valid/11/image_03139.jpg
# valid/11/image_03108.jpg
# valid/3/
# valid/3/image_06631.jpg
# valid/3/image_06621.jpg
# valid/8/
# valid/8/image_03366.jpg
# valid/8/image_03349.jpg
# valid/8/image_03313.jpg
# valid/8/image_03330.jpg
# valid/8/image_03342.jpg
# valid/67/
# valid/67/image_07075.jpg
# valid/67/image_07083.jpg
# valid/5/
# valid/5/image_05164.jpg
# valid/5/image_05196.jpg
# valid/5/image_05168.jpg
# valid/5/image_05199.jpg
# valid/5/image_05192.jpg
# valid/5/image_05209.jpg
# valid/5/image_05188.jpg
# valid/79/
# valid/79/image_06707.jpg
# valid/79/image_06728.jpg
# valid/79/image_06718.jpg
# valid/79/image_06695.jpg
# valid/20/
# valid/20/image_04913.jpg
# valid/20/image_04918.jpg
# valid/20/image_04942.jpg
# valid/20/image_04940.jpg
# valid/20/image_04920.jpg
# valid/20/image_04903.jpg
# valid/20/image_04927.jpg

# %%
# Imports here
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
import torch
from torch import nn, optim
from torch.optim import lr_scheduler
from torch.autograd import Variable
import torchvision
import torch.utils.data as data
from torchvision import datasets, models, transforms
import time
import json
import copy
import seaborn as sns
import numpy as np
from PIL import Image
from collections import OrderedDict
import matplotlib.pyplot as plt

# %% [markdown]
# #Load Data
# We will use torchvision and torch.utils.data packages for loading the data.
# For the training, i have applied transformations such as random scaling, cropping, and flipping. This will help the network generalize leading to better performance. I also made it sure that the input data is resized to 224x224 pixels as required by the pre-trained networks.
#
# The validation and testing sets are used to measure the model's performance on data it hasn't seen yet. For this i have not performed any scaling or rotation transformations, but i had resized and then cropped the images to the appropriate size.
#
# The pre-trained networki have used was trained on the ImageNet dataset where each color channel was normalized separately. For all three sets i have normalized the means and standard deviations of the images to what the network expects. For the means, it's [0.485, 0.456, 0.406] and for the standard deviations [0.229, 0.224, 0.225], calculated from the ImageNet images. These values will shift each color channel to be centered at 0 and range from -1 to 1.

# %%
data_dir = '.'
train_dir = data_dir + '/train'
valid_dir = data_dir + '/valid'
test_dir = data_dir + '/test'

# %%
# TODO: Define your transforms for the training, validation, and testing sets
# defining data transforms for training, validation and test data and also normalizing whole data
data_transforms = {
        'train': transforms.Compose([
            transforms.Resize(256),
            transforms.CenterCrop(224),
            #transforms.RandomRotation(45),
            transforms.RandomHorizontalFlip(),
            transforms.ToTensor(),
            transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
         ]),
        'valid': transforms.Compose([
            transforms.Resize(256),
            transforms.CenterCrop(224),
            transforms.ToTensor(),
            transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
         ]),
        'test': transforms.Compose([
            transforms.Resize(256),
            transforms.CenterCrop(224),
            transforms.ToTensor(),
            transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
         ])
    }

# TODO: Load the datasets with ImageFolder
# loading datasets with PyTorch ImageFolder
image_datasets = {
        x: datasets.ImageFolder(root=data_dir + '/' + x, transform=data_transforms[x])
        for x in list(data_transforms.keys())
    }

# TODO: Using the image datasets and the trainforms, define the dataloaders
# defining data loaders to load data using image_datasets and transforms, here we also specify batch size for the mini batch
dataloaders = {
        x: data.DataLoader(image_datasets[x], batch_size=4, shuffle=True, num_workers=2)
        for x in list(image_datasets.keys())
    }
dataset_sizes = {
        x: len(dataloaders[x].dataset) 
        for x in list(image_datasets.keys())
    } 
class_names = image_datasets['train'].classes

# %%
dataset_sizes # printing dataset's sizes for training, validation and testing
# Out:
# {'test': 819, 'train': 6552, 'valid': 818}

# %% [markdown]
# #Label mapping
# I had load in a mapping from category label to category name. I got this in the file cat_to_name.json. It's a JSON object which i have read in with the json module. This gave a dictionary mapping the integer encoded categories to the actual names of the flowers.

# %%
import json

with open('drive/My Drive/cat_to_name.json', 'r') as f:
    cat_to_name = json.load(f)

# %%
# changing categories to their actual names 
for i in range(0,len(class_names)):
    class_names[i] = cat_to_name.get(class_names[i])

# %% [markdown]
# #Visualize a few images
# Let's visualize a few training images so as to understand the data augmentations.

# %%
def imshow(inp, title=None):
    """Imshow for Tensor."""
    inp = inp.numpy().transpose((1, 2, 0))
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    inp = std * inp + mean
    inp = np.clip(inp, 0, 1)
    plt.imshow(inp)
    if title is not None:
        plt.title(title)
    plt.pause(0.001)  # pause a bit so that plots are updated


# Get a batch of training data
inputs, classes = next(iter(dataloaders['train']))

# Make a grid from batch
out = torchvision.utils.make_grid(inputs)

imshow(out, title=[class_names[x] for x in classes])

# %%
import sys
sys.path.append('/content/drive/My Drive/efficientnet-pytorch-master')
sys.path
# Out:
# ['',
#  '/env/python',
#  '/usr/lib/python36.zip',
#  '/usr/lib/python3.6',
#  '/usr/lib/python3.6/lib-dynload',
#  '/usr/local/lib/python3.6/dist-packages',
#  '/usr/lib/python3/dist-packages',
#  '/usr/local/lib/python3.6/dist-packages/IPython/extensions',
#  '/root/.ipython',
#  '/content/drive/My Drive/efficientnet-pytorch-master']

# %% [markdown]
# #Finetuning the convnet
# Load a pretrained Resnet 18 model and reset final fully connected layer.

# %%
# !pip install mlconfig
from efficientnet.models.efficientnet import EfficientNet, params


def numel(model):
    return sum(p.numel() for p in model.parameters())


def test_output(model, size):
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

    model.to(device)
    model.eval()

    x = torch.randn(1, 3, size, size).to(device)
    with torch.no_grad():
        y = model(x)
        print('output size: ', y.size(1))


def print_num_parameters(model):
    num_params = numel(model)
    print(f'Number of parameters: {num_params}')


for arch, (w, d, s, r) in params.items():
    model = EfficientNet(w, d, r)

    print(f'Arch: {arch}, settings: {(w, d, s, r)}')
    test_output(model, s)
    print_num_parameters(model)

model_ft = EfficientNet(width_mult=1, depth_mult=1, dropout_rate=0.2, num_classes=102)
test_output(model_ft, 224)
print_num_parameters(model_ft)
#model_ft = models.resnet18(pretrained=True) # loading a pre-trained(trained on image net) resnet18 model from torchvision models
#num_ftrs = model_ft.fc.in_features
#model_ft.fc = nn.Linear(num_ftrs, 102) # changing the last layer for this dataset by setting last layer neurons to 102 as this dataset has 102 categories
# Out:
# Collecting mlconfig
#   Downloading https://files.pythonhosted.org/packages/40/97/17bd024a52daa29e94cc5934c43eb109cb182eee99957304b46e96f27672/mlconfig-0.0.6-py3-none-any.whl
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.6/dist-packages (from mlconfig) (3.13)
# Installing collected packages: mlconfig
# Successfully installed mlconfig-0.0.6
# Arch: efficientnet_b0, settings: (1.0, 1.0, 224, 0.2)
# output size:  1000
# Number of parameters: 5288548
# Arch: efficientnet_b1, settings: (1.0, 1.1, 240, 0.2)
# output size:  1000
# Number of parameters: 7794184
# Arch: efficientnet_b2, settings: (1.1, 1.2, 260, 0.3)
# output size:  1000
# Number of parameters: 9109994
# Arch: efficientnet_b3, settings: (1.2, 1.4, 300, 0.3)
# output size:  1000
# Number of parameters: 12233232
# Arch: efficientnet_b4, settings: (1.4, 1.8, 380, 0.4)
# output size:  1000
# Number of parameters: 19341616
# Arch: efficientnet_b5, settings: (1.6, 2.2, 456, 0.4)
# output size:  1000
# Number of parameters: 30389784
# Arch: efficientnet_b6, settings: (1.8, 2.6, 528, 0.5)
# output size:  1000
# Number of parameters: 43040704
# Arch: efficientnet_b7, settings: (0.9, 0.8, 195, 0.2)
# output size:  1000
# Number of parameters: 4537832
# output size:  102
# Number of parameters: 4138210

# %% [markdown]
# [링크 텍스트](https://)You can load a checkpoint from your my drive or any other place if you have saved it. you have to load weights of model and optimizer

# %%
#checkpoint = torch.load('point_efficientnet_best.pth')
#model_ft.load_state_dict(checkpoint['model'])
#optimizer_ft.load_state_dict(checkpoint['optim'])

# %%
use_gpu = torch.cuda.is_available() # if gpu is available then use it
if use_gpu:
    model_ft = model_ft.cuda()

criterion = nn.CrossEntropyLoss() # defining loss function


optimizer_ft = optim.SGD(model_ft.parameters(), lr=0.001, momentum=0.9) # defining optimizer with learning rate set to 0.0001

# %% [markdown]
# #Training the model
# Now, let's write a general function to train a model.
# I also have written code to save the best checkpoint within Google drive for using next time

# %%
def train_model(model, criterion, optimizer, num_epochs=10):
    since = time.time()

    best_model_wts = model.state_dict()
    best_acc = 0.0

    for epoch in range(num_epochs):
        print('Epoch {}/{}'.format(epoch, num_epochs - 1))
        print('-' * 10)

        # Each epoch has a training and validation phase
        for phase in ['train', 'valid']:
            if phase == 'train':
                #scheduler.step()
                model.train(True)  # Set model to training mode
            else:
                model.train(False)  # Set model to evaluate mode

            running_loss = 0.0
            running_corrects = 0

            # Iterate over data.
            for data in dataloaders[phase]:
                # get the inputs
                inputs, labels = data

                # wrap them in Variable
                if use_gpu:
                    inputs = Variable(inputs.cuda())
                    labels = Variable(labels.cuda())
                else:
                    inputs, labels = Variable(inputs), Variable(labels)

                # zero the parameter gradients
                optimizer.zero_grad()

                # forward
                outputs = model(inputs)
                
                _, preds = torch.max(outputs.data, 1)
                loss = criterion(outputs, labels)

                # backward + optimize only if in training phase
                if phase == 'train':
                    loss.backward()
                    optimizer.step()

                # statistics
                running_loss += loss.item()
                running_corrects += torch.sum(preds == labels.data, dtype=torch.float)

            epoch_loss = running_loss / dataset_sizes[phase]
            epoch_acc = running_corrects / dataset_sizes[phase]

            print('{} Loss: {:.4f} Acc: {:.4f}'.format(
                phase, epoch_loss, epoch_acc))

            # deep copy the model
            if phase == 'valid' and epoch_acc > best_acc:
                best_acc = epoch_acc
                best_model_wts = model.state_dict()
                # saving a checkpoint to use for next time to save time used in training from scratch
                state = {'model':model.state_dict(),'optim':optimizer.state_dict()}
                torch.save(state, 'point_efficientnet_best.pth')

        print()

    time_elapsed = time.time() - since
    print('Training complete in {:.0f}m {:.0f}s'.format(
        time_elapsed // 60, time_elapsed % 60))
    print('Best val Acc: {:4f}'.format(best_acc))

    # load best model weights
    model.load_state_dict(best_model_wts)
    return model

# %% [markdown]
# #Visualizing the model predictions
# Generic function to display predictions for a few images

# %%
def visualize_model(model, num_images=8):
    images_so_far = 0
    fig = plt.figure()
    

    for i, data in enumerate(dataloaders['valid']):
        inputs, labels = data
        #print(labels)
        if use_gpu:
            inputs, labels = Variable(inputs.cuda()), Variable(labels.cuda())
        else:
            inputs, labels = Variable(inputs), Variable(labels)
        outputs = model(inputs)
        _, preds = torch.max(outputs.data, 1)

        for j in range(inputs.size()[0]):
            images_so_far += 1
            ax = plt.subplot(num_images//2, 2, images_so_far)
            ax.axis('off')
            ax.set_title('class: {} predicted: {}'.format(class_names[labels.data[j]], class_names[preds[j]]))
            imshow(inputs.cpu().data[j])

            if images_so_far == num_images:
                return

# %% [markdown]
# #Train and evaluate

# %%
model_ft = train_model(model_ft, criterion, optimizer_ft, num_epochs=20)
# Out:
# Epoch 0/19
# ----------
# train Loss: 1.0971 Acc: 0.0464
# valid Loss: 11.2816 Acc: 0.0758
#
# Epoch 1/19
# ----------
# train Loss: 0.9983 Acc: 0.0849
# valid Loss: 1.3555 Acc: 0.1064
#
# Epoch 2/19
# ----------
# train Loss: 0.9191 Acc: 0.1302
# valid Loss: 0.9533 Acc: 0.1956
#
# Epoch 3/19
# ----------
# train Loss: 0.8476 Acc: 0.1667
# valid Loss: 0.8323 Acc: 0.2286
#
# Epoch 4/19
# ----------
# train Loss: 0.7827 Acc: 0.2213
# valid Loss: 0.6448 Acc: 0.3472
#
# Epoch 5/19
# ----------
# train Loss: 0.7215 Acc: 0.2730
# valid Loss: 0.6261 Acc: 0.4010
#
# Epoch 6/19
# ----------
# train Loss: 0.6630 Acc: 0.3342
# valid Loss: 0.5309 Acc: 0.4853
#
# Epoch 7/19
# ----------
# train Loss: 0.6056 Acc: 0.3907
# valid Loss: 0.4937 Acc: 0.5171
#
# Epoch 8/19
# ----------
# train Loss: 0.5615 Acc: 0.4214
# valid Loss: 0.4485 Acc: 0.5513
#
# Epoch 9/19
# ----------
# train Loss: 0.5137 Acc: 0.4623
# valid Loss: 0.3945 Acc: 0.6186
#
# Epoch 10/19
# ----------
# train Loss: 0.4681 Acc: 0.5089
# valid Loss: 0.4094 Acc: 0.6198
#
# Epoch 11/19
# ----------
# train Loss: 0.4302 Acc: 0.5475
# valid Loss: 0.3340 Acc: 0.6846
#
# Epoch 12/19
# ----------
# train Loss: 0.3986 Acc: 0.5726
# valid Loss: 0.3384 Acc: 0.6773
#
# Epoch 13/19
# ----------
# train Loss: 0.3639 Acc: 0.6119
# valid Loss: 0.2882 Acc: 0.7103
#
# Epoch 14/19
# ----------
# train Loss: 0.3394 Acc: 0.6352
# valid Loss: 0.2566 Acc: 0.7298
#
# Epoch 15/19
# ----------
# train Loss: 0.3137 Acc: 0.6563
# valid Loss: 0.2505 Acc: 0.7482
#
# Epoch 16/19
# ----------
# train Loss: 0.2823 Acc: 0.6897
# valid Loss: 0.2199 Acc: 0.7800
#
# Epoch 17/19
# ----------
# train Loss: 0.2643 Acc: 0.7097
# valid Loss: 0.2079 Acc: 0.7934
#
# Epoch 18/19
# ----------
# train Loss: 0.2418 Acc: 0.7370
# valid Loss: 0.2110 Acc: 0.8056
#
# Epoch 19/19
# ----------
# train Loss: 0.2297 Acc: 0.7459
# valid Loss: 0.1865 Acc: 0.8105
#
# Training complete in 40m 36s
# Best val Acc: 0.810513

# %% [markdown]
# # Checking Model's Predictions

# %%
visualize_model(model_ft)

# %% [markdown]
# #Checking model's accuracy on test set(This is top-1 accuracy)

# %%
def calc_accuracy(model, data):
    model.eval()
    if use_gpu:
      model.cuda()    
    running_corrects = 0
    test_acc = 0
    
    #with torch.no_grad():
    for idx, (inputs, labels) in enumerate(dataloaders[data]):
        if use_gpu:
            inputs, labels = inputs.cuda(), labels.cuda()
        # obtain the outputs from the model
        outputs = model.forward(Variable(inputs))
        # max provides the (maximum probability, max value)
        #_, predicted = outputs.max(dim=1)
        _, predicted = torch.max(outputs.data, 1)
        running_corrects += torch.sum(predicted == labels, dtype=torch.float)
    test_acc = running_corrects / dataset_sizes['test']
    print('Test Accuracy: {:.4f}'.format(test_acc))
    '''# check the 
    if idx == 0:
        print(predicted) #the predicted class
        print(torch.exp(_)) # the predicted probability
    equals = predicted == labels.data
    if idx == 0:
        print(equals)
    print(equals.float().mean())'''
calc_accuracy(model_ft, 'test')
# Out:
# Test Accuracy: 0.7973

# %% [markdown]
# #Preparation for finding top-5 accuracy
# Here i have defined a use full class and a function to find top-1 and top-5 accuracies

# %%
class AverageMeter(object):
    """Computes and stores the average and current value"""
    def __init__(self):
        self.reset()

    def reset(self):
        self.val = 0
        self.avg = 0
        self.sum = 0
        self.count = 0

    def update(self, val, n=1):
        self.val = val
        self.sum += val * n
        self.count += n
        self.avg = self.sum / self.count

# %%
def accuracy(output, target, topk=(1,)):
    """Computes the precision@k for the specified values of k"""
    #with torch.no_grad():
    maxk = max(topk)
    batch_size = target.size(0)

    _, pred = output.topk(maxk, 1, True, True)
    pred = pred.t()
    correct = pred.eq(target.view(1, -1).expand_as(pred))

    res = []
    for k in topk:
        correct_k = correct[:k].view(-1).float().sum(0, keepdim=True)
        res.append(correct_k.mul_(100.0 / batch_size))
    return res

# %%
def calc_accuracy(model, data):
    model.eval()
    if use_gpu:
      model.cuda()    
    running_corrects = 0
    test_acc = 0
    top1 = AverageMeter()
    top5 = AverageMeter()
    
    for idx, (inputs, labels) in enumerate(dataloaders[data]):
        if use_gpu:
            inputs, labels = inputs.cuda(), labels.cuda()
        # obtain the outputs from the model
        outputs = model.forward(Variable(inputs))
        prec1, prec5 = accuracy(outputs, Variable(labels), topk=(1, 5))
        top1.update(prec1[0], inputs.size(0))
        top5.update(prec5[0], inputs.size(0))
        
    return top1 ,top5
    
top1 ,top5 = calc_accuracy(model_ft, 'test')

# %% [markdown]
# #Top-1 Accuracy

# %%
top1.avg
# Out:
# tensor(79.7314, device='cuda:0')

# %% [markdown]
# #Top-5 Accuracy

# %%
top5.avg
# Out:
# tensor(94.7497, device='cuda:0')

# %% [markdown]
# #Inference for classification
# Now I have written a function to use a trained network for inference. That is, I'll pass an image into the network and predict the class of the flower in the image. I have written a function called predict that takes an image and a model, then returns the top  K  most likely classes along with the probabilities. It should look like
#
# probs, classes = predict(image_path, model)
# print(probs)
# print(classes)
# > [ 0.01558163  0.01541934  0.01452626  0.01443549  0.01407339]
# > ['70', '3', '45', '62', '55']
# First I have to handle processing the input image such that it can be used in my network.
#
# #Image Preprocessing
# I want to use PIL to load the image . It's best to write a function that preprocesses the image so it can be used as input for the model. This function should process the images in the same manner used for training.
#
# First, I resized the images where the shortest side is 256 pixels, keeping the aspect ratio. This has  done with the thumbnail or resize methods. Then I have cropped out the center 224x224 portion of the image.
#
# Color channels of images are typically encoded as integers 0-255, but the model expected floats 0-1. I have converted the values. It's easiest with a Numpy array, which I had got from a PIL image like so np_image = np.array(pil_image).
#
# As before, the network expects the images to be normalized in a specific way. For the means, it's [0.485, 0.456, 0.406] and for the standard deviations [0.229, 0.224, 0.225]. I had subtracted the means from each color channel, then divided by the standard deviation.
#
# And finally, PyTorch expects the color channel to be the first dimension but it's the third dimension in the PIL image and Numpy array. I have reordered dimensions using ndarray.transpose. The color channel needs to be first and retain the order of the other two dimensions.

# %%
def process_image(image_path):
    ''' 
    Scales, crops, and normalizes a PIL image for a PyTorch       
    model, returns an Numpy array
    '''
    # Open the image
    from PIL import Image
    img = Image.open(image_path)
    # Resize
    if img.size[0] > img.size[1]:
        img.thumbnail((10000, 256))
    else:
        img.thumbnail((256, 10000))
    # Crop 
    left_margin = (img.width-224)/2
    bottom_margin = (img.height-224)/2
    right_margin = left_margin + 224
    top_margin = bottom_margin + 224
    img = img.crop((left_margin, bottom_margin, right_margin,   
                      top_margin))
    # Normalize
    img = np.array(img)/255
    mean = np.array([0.485, 0.456, 0.406]) #provided mean
    std = np.array([0.229, 0.224, 0.225]) #provided std
    img = (img - mean)/std
    
    # Move color channels to first dimension as expected by PyTorch
    img = img.transpose((2, 0, 1))
    
    return img

# %%
def imshow(image, ax=None, title=None):
    if ax is None:
        fig, ax = plt.subplots()
    if title:
        plt.title(title)
    # PyTorch tensors assume the color channel is first
    # but matplotlib assumes is the third dimension
    image = image.transpose((1, 2, 0))
    
    # Undo preprocessing
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    image = std * image + mean
    
    # Image needs to be clipped between 0 and 1
    image = np.clip(image, 0, 1)
    
    ax.imshow(image)
    
    return ax

# %%
image_path = 'test/1/image_06752.jpg'
img = process_image(image_path)
imshow(img)

# %% [markdown]
# #Class Prediction
# OnceI have got images in the correct format, I have written a function for making predictions with my model. A common practice is to predict the top 5 or so (usually called top- K ) most probable classes. I have calculated the class probabilities then find the  K  largest values.
#
# To get the top  K  largest values in a tensor I have used x.topk(k). This method returns both the highest k probabilities and the indices of those probabilities corresponding to the classes. I have converted these indices to image names using class_names got from cat_to_name.json

# %%
def predict(image_path, model, top_num=5):
    # Process image
    img = process_image(image_path)
    
    # Numpy -> Tensor
    image_tensor = torch.from_numpy(img).type(torch.FloatTensor)
    # Add batch of size 1 to image
    model_input = image_tensor.unsqueeze(0)
    
    # Probs
    probs = torch.exp(model.forward(Variable(model_input.cuda())))
    
    # Top probs
    top_probs, top_labs = probs.topk(top_num)
    top_probs, top_labs =top_probs.data, top_labs.data
    top_probs = top_probs.cpu().numpy().tolist()[0] 
    top_labs = top_labs.cpu().numpy().tolist()[0]
    #print(top_labs)
    # Convert indices to classes
    '''idx_to_class = {val: key for key, val in    
                                      model.class_to_idx.items()}
    top_labels = [idx_to_class[lab] for lab in top_labs]
    top_flowers = [cat_to_name[idx_to_class[lab]] for lab in top_labs]'''
    top_flowers = [class_names[lab] for lab in top_labs]
    return top_probs, top_flowers

# %% [markdown]
# #Sanity Checking
# Now I have used a trained model for predictions. Even if the testing accuracy is high, it's always good to check that there aren't obvious bugs. I have used matplotlib to plot the probabilities for the top 5 classes as a bar graph, along with the input image.

# %%
def plot_solution(image_path, model):
    # Set up plot
    plt.figure(figsize = (6,10))
    ax = plt.subplot(2,1,1)
    # Set up title
    flower_num = image_path.split('/')[1]
    title_ = cat_to_name[flower_num]
    # Plot flower
    img = process_image(image_path)
    imshow(img, ax, title = title_);
    # Make prediction
    probs, flowers = predict(image_path, model) 
    # Plot bar chart
    plt.subplot(2,1,2)
    sns.barplot(x=probs, y=flowers, color=sns.color_palette()[0]);
    plt.show()
image_path = 'test/90/image_04432.jpg'
plot_solution(image_path, model_ft)
